# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !apt-get update
# !apt-get install -y gromacs gromacs-mpi
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,678 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,003 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,763 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,237 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,692 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,962 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,535 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [38.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [112 kB]
# Fetched 24.4 MB in 3s (8,438 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-mathjax gromacs-data libfftw3-double3 libfftw3-single3 libgromacs6 libjs-mathjax
#   sse4.2-support
# Suggested packages:
#   pymol libfftw3-bin libfftw3-dev fonts-mathjax-extras fonts-stix libjs-mathjax-doc
# The following NEW packages will be installed:
#   fonts-mathjax gromacs gromacs-data gromacs-mpi libfftw3-double3 libfftw3-single3 libgromacs6
#   libjs-mathjax sse4.2-support
# 0 upgraded, 9 newly installed, 0 to remove and 30 not upgraded.
# Need to get 65.5 MB of archives.
# After this operation, 328 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 sse4.2-support amd64 6 [8,572 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-mathjax all 2.7.9+dfsg-1 [2,208 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gromacs-mpi amd64 2021.4-2 [7,241 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgromacs6 amd64 2021.4-2 [12.3 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-mathjax all 2.7.9+dfsg-1 [5,665 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gromacs-data all 2021.4-2 [36.3 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gromacs amd64 2021.4-2 [131 kB]
# Fetched 65.5 MB in 2s (34.4 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package sse4.2-support.
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../0-sse4.2-support_6_amd64.deb ...
# Unpacking sse4.2-support (6) ...
# Selecting previously unselected package fonts-mathjax.
# Preparing to unpack .../1-fonts-mathjax_2.7.9+dfsg-1_all.deb ...
# Unpacking fonts-mathjax (2.7.9+dfsg-1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../2-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../3-libfftw3-single3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package gromacs-mpi.
# Preparing to unpack .../4-gromacs-mpi_2021.4-2_amd64.deb ...
# Unpacking gromacs-mpi (2021.4-2) ...
# Selecting previously unselected package libgromacs6:amd64.
# Preparing to unpack .../5-libgromacs6_2021.4-2_amd64.deb ...
# Unpacking libgromacs6:amd64 (2021.4-2) ...
# Selecting previously unselected package libjs-mathjax.
# Preparing to unpack .../6-libjs-mathjax_2.7.9+dfsg-1_all.deb ...
# Unpacking libjs-mathjax (2.7.9+dfsg-1) ...
# Selecting previously unselected package gromacs-data.
# Preparing to unpack .../7-gromacs-data_2021.4-2_all.deb ...
# Unpacking gromacs-data (2021.4-2) ...
# Selecting previously unselected package gromacs.
# Preparing to unpack .../8-gromacs_2021.4-2_amd64.deb ...
# Unpacking gromacs (2021.4-2) ...
# Setting up fonts-mathjax (2.7.9+dfsg-1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libjs-mathjax (2.7.9+dfsg-1) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up sse4.2-support (6) ...
# Setting up libgromacs6:amd64 (2021.4-2) ...
# Setting up gromacs-mpi (2021.4-2) ...
# Setting up gromacs-data (2021.4-2) ...
# Setting up gromacs (2021.4-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx --version
# Out:
#                  :-) GROMACS - gmx, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content
# Command line:
#   gmx --version
#
# GROMACS version:    2021.4-Ubuntu-2021.4-2
# Precision:          mixed
# Memory model:       64 bit
# MPI library:        thread_mpi
# OpenMP support:     enabled (GMX_OPENMP_MAX_THREADS = 64)
# GPU support:        disabled
# SIMD instructions:  SSE4.1
# FFT library:        fftw-3.3.8-sse2-avx
# RDTSCP usage:       enabled
# TNG support:        enabled
# Hwloc support:      hwloc-2.5.0
# Tracing support:    disabled
# C compiler:         /usr/bin/cc GNU 11.2.0
# C compiler flags:   -msse4.1 -Wno-missing-field-initializers -fexcess-precision=fast -funroll-all-loops -O3 -DNDEBUG
# C++ compiler:       /usr/bin/c++ GNU 11.2.0
# C++ compiler flags: -msse4.1 -Wno-missing-field-initializers -fexcess-precision=fast -funroll-all-loops -fopenmp -O3 -DNDEBUG

# %% [markdown]
# ### Install necessary Python packages.

# %%
# !pip install MDAnalysis
# Out:
# Collecting MDAnalysis
#   Downloading mdanalysis-2.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (2.0.2)
# Collecting GridDataFormats>=0.4.0 (from MDAnalysis)
#   Downloading GridDataFormats-1.0.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting mmtf-python>=1.0.0 (from MDAnalysis)
#   Downloading mmtf_python-1.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (1.14.1)
# Requirement already satisfied: matplotlib>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (4.67.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (3.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from MDAnalysis) (3.18.0)
# Collecting mda-xdrlib (from MDAnalysis)
#   Downloading mda_xdrlib-0.2.0-py3-none-any.whl.metadata (19 kB)
# Collecting mrcfile (from GridDataFormats>=0.4.0->MDAnalysis)
#   Downloading mrcfile-1.5.4-py2.py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis) (2.8.2)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from mmtf-python>=1.0.0->MDAnalysis) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=1.5.1->MDAnalysis) (1.17.0)
# Downloading mdanalysis-2.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 113.7 MB/s eta 0:00:00
# Downloading GridDataFormats-1.0.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.3 MB/s eta 0:00:00
# Downloading mmtf_python-1.1.3-py2.py3-none-any.whl (25 kB)
# Downloading mda_xdrlib-0.2.0-py3-none-any.whl (14 kB)
# Downloading mrcfile-1.5.4-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: mrcfile, mmtf-python, mda-xdrlib, GridDataFormats, MDAnalysis
# Successfully installed GridDataFormats-1.0.2 MDAnalysis-2.9.0 mda-xdrlib-0.2.0 mmtf-python-1.1.3 mrcfile-1.5.4

# %% [markdown]
# ### Install necessary Python packages.

# %%
# !pip install MDAnalysis[analysis] freesasa
# Out:
# Collecting freesasa
#   Downloading freesasa-2.2.1.tar.gz (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MDAnalysis[analysis] in /usr/local/lib/python3.11/dist-packages (2.9.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (2.0.2)
# Requirement already satisfied: GridDataFormats>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (1.0.2)
# Requirement already satisfied: mmtf-python>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (1.1.3)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (1.14.1)
# Requirement already satisfied: matplotlib>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (4.67.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (3.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (3.18.0)
# Requirement already satisfied: mda-xdrlib in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (0.2.0)
# Collecting biopython>=1.80 (from MDAnalysis[analysis])
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (1.6.1)
# Collecting tidynamics>=1.0.0 (from MDAnalysis[analysis])
#   Downloading tidynamics-1.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.11/dist-packages (from MDAnalysis[analysis]) (3.4.2)
# Collecting waterdynamics (from MDAnalysis[analysis])
#   Downloading waterdynamics-1.2.0-py3-none-any.whl.metadata (37 kB)
# Collecting pathsimanalysis (from MDAnalysis[analysis])
#   Downloading pathsimanalysis-1.2.0-py3-none-any.whl.metadata (37 kB)
# Collecting mdahole2 (from MDAnalysis[analysis])
#   Downloading mdahole2-0.5.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: mrcfile in /usr/local/lib/python3.11/dist-packages (from GridDataFormats>=0.4.0->MDAnalysis[analysis]) (1.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5.1->MDAnalysis[analysis]) (2.8.2)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from mmtf-python>=1.0.0->MDAnalysis[analysis]) (1.1.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn->MDAnalysis[analysis]) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn->MDAnalysis[analysis]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn->MDAnalysis[analysis]) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=1.5.1->MDAnalysis[analysis]) (1.17.0)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 76.7 MB/s eta 0:00:00
# Downloading tidynamics-1.1.2-py3-none-any.whl (6.5 kB)
# Downloading mdahole2-0.5.0-py3-none-any.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 102.0 MB/s eta 0:00:00
# Downloading pathsimanalysis-1.2.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 4.6 MB/s eta 0:00:00
# Downloading waterdynamics-1.2.0-py3-none-any.whl (35 kB)
# Building wheels for collected packages: freesasa
#   Building wheel for freesasa (setup.py) ... done
#   Created wheel for freesasa: filename=freesasa-2.2.1-cp311-cp311-linux_x86_64.whl size=888785 sha256=3986cb0601f5c53d1905041f146f798454b777478680ff4a2f7ba35b0a776ba9
#   Stored in directory: /root/.cache/pip/wheels/12/7e/68/f3f59a0c5946b122ecbf6098c87de4c8a1f73ec145c077815b
# Successfully built freesasa
# Installing collected packages: freesasa, tidynamics, biopython, waterdynamics, pathsimanalysis, mdahole2
# Successfully installed biopython-1.85 freesasa-2.2.1 mdahole2-0.5.0 pathsimanalysis-1.2.0 tidynamics-1.1.2 waterdynamics-1.2.0

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !mkdir -p /content/drive/MyDrive/Rayca_eval/MD_simulation

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# %cd /content/drive/MyDrive/Rayca_eval/MD_simulation
# Out:
# /content/drive/MyDrive/Rayca_eval/MD_simulation

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !echo 15 | gmx pdb2gmx -f /content/drive/MyDrive/Rayca_eval/Data/pocket2_residues_dock_prep.pdb \
-o best_pocket.gro -water spce -ignh
# Out:
#              :-) GROMACS - gmx pdb2gmx, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx pdb2gmx, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx pdb2gmx -f /content/drive/MyDrive/Rayca_eval/Data/pocket2_residues_dock_prep.pdb -o best_pocket.gro -water spce -ignh
#
# Select the Force Field:
#
# From '/usr/share/gromacs/top':
#
#  1: AMBER03 protein, nucleic AMBER94 (Duan et al., J. Comp. Chem. 24, 1999-2012, 2003)
#
#  2: AMBER94 force field (Cornell et al., JACS 117, 5179-5197, 1995)
#
#  3: AMBER96 protein, nucleic AMBER94 (Kollman et al., Acc. Chem. Res. 29, 461-469, 1996)
#
#  4: AMBER99 protein, nucleic AMBER94 (Wang et al., J. Comp. Chem. 21, 1049-1074, 2000)
#
#  5: AMBER99SB protein, nucleic AMBER94 (Hornak et al., Proteins 65, 712-725, 2006)
#
#  6: AMBER99SB-ILDN protein, nucleic AMBER94 (Lindorff-Larsen et al., Proteins 78, 1950-58, 2010)
#
#  7: AMBERGS force field (Garcia & Sanbonmatsu, PNAS 99, 2782-2787, 2002)
#
#  8: CHARMM27 all-atom force field (CHARM22 plus CMAP for proteins)
#
#  9: GROMOS96 43a1 force field
#
# 10: GROMOS96 43a2 force field (improved alkane dihedrals)
#
# 11: GROMOS96 45a3 force field (Schuler JCC 2001 22 1205)
#
# 12: GROMOS96 53a5 force field (JCC 2004 vol 25 pag 1656)
#
# 13: GROMOS96 53a6 force field (JCC 2004 vol 25 pag 1656)
#
# 14: GROMOS96 54a7 force field (Eur. Biophys. J. (2011), 40,, 843-856, DOI: 10.1007/s00249-011-0700-9)
#
# 15: OPLS-AA/L all-atom force field (2001 aminoacid dihedrals)
#
# Using the Oplsaa force field in directory oplsaa.ff
#
# going to rename oplsaa.ff/aminoacids.r2b
# Opening force field file /usr/share/gromacs/top/oplsaa.ff/aminoacids.r2b
# Reading /content/drive/MyDrive/Rayca_eval/Data/pocket2_residues_dock_prep.pdb...
# WARNING: all CONECT records are ignored
# Read '', 73 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
#
# There are 1 chains and 0 blocks of water and 9 residues with 73 atoms
#
#   chain  #res #atoms
#
#   1 'A'     9     73
#
# All occupancies are one
# All occupancies are one
# Opening force field file /usr/share/gromacs/top/oplsaa.ff/atomtypes.atp
#
# Reading residue database... (Oplsaa)
# Opening force field file /usr/share/gromacs/top/oplsaa.ff/aminoacids.rtp
# Opening force field file /usr/share/gromacs/top/oplsaa.ff/aminoacids.hdb
# Opening force field file /usr/share/gromacs/top/oplsaa.ff/aminoacids.n.tdb
# Opening force field file /usr/share/gromacs/top/oplsaa.ff/aminoacids.c.tdb
#
# Processing chain 1 'A' (73 atoms, 9 residues)
#
# Identified residue LEU27 as a starting terminus.
#
# Identified residue PRO216 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
# Start terminus LEU-27: NH3+
# End terminus PRO-216: PRO-COO-
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 9 residues with 151 atoms
#
# Making bonds...
#
# Long Bond (20-22 = 0.420923 nm)
#
# Long Bond (20-22 = 0.420923 nm)
#
# Long Bond (36-38 = 0.561717 nm)
#
# Long Bond (36-38 = 0.561717 nm)
#
# Long Bond (88-90 = 0.518883 nm)
#
# Long Bond (88-90 = 0.518883 nm)
#
# Long Bond (123-125 = 0.802763 nm)
#
# Long Bond (123-125 = 0.802763 nm)
#
# Number of bonds was 153, now 153
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 409 pairs
# Before cleaning: 419 dihedrals
# Keeping all generated dihedrals
#
# Making cmap torsions...
#
# There are  419 dihedrals,   26 impropers,  283 angles
#            406 pairs,      153 bonds and     0 virtual sites
#
# Total mass 1044.216 a.m.u.
#
# Total charge -0.000 e
#
# Writing topology
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: /content/drive/MyDrive/Rayca_eval/Data/pocket2_residues_dock_prep.pdb.
#
# The Oplsaa force field and the spce water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "Working in the Burger Kings, Spitting on your Onion Rings" (Slim Shady)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx editconf -f best_pocket.gro -o pocket_box.gro -c -d 1.0 -bt cubic
# Out:
#              :-) GROMACS - gmx editconf, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx editconf -f best_pocket.gro -o pocket_box.gro -c -d 1.0 -bt cubic
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 151 atoms
# Volume: 577.32 nm^3, corresponds to roughly 259700 electrons
# No velocities found
#     system size :  1.613  1.288  2.075 (nm)
#     diameter    :  2.113               (nm)
#     center      :  2.359 -1.069 -4.575 (nm)
#     box vectors :  5.646  6.394 15.992 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 577.32               (nm^3)
#     shift       : -0.302  3.125  6.631 (nm)
# new center      :  2.056  2.056  2.056 (nm)
# new box vectors :  4.113  4.113  4.113 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :  69.56               (nm^3)
#
# GROMACS reminds you: "I Got a Forty Dollar Bill" (F. Zappa)

# %% [markdown]
# ### Save analysis results or plots to file.

# %%
# %%writefile /content/drive/MyDrive/Rayca_eval/MD_simulation/ions.mdp
# ; ions.mdp - Used for ion addition
# integrator               = steep
# emtol                    = 1000.0
# emstep                   = 0.01
# nsteps                   = 50000
# nstlist                  = 1
# cutoff-scheme            = Verlet
# ns_type                  = grid
# rlist                    = 1.0
# coulombtype              = PME
# rcoulomb                 = 1.0
# vdw-type                 = cutoff
# rvdw                     = 1.0
# pbc                      = xyz
# Out:
# Writing /content/drive/MyDrive/Rayca_eval/MD_simulation/ions.mdp

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx solvate -cp pocket_box.gro -cs spc216.gro -o solvated_pocket.gro -p topol.top
# Out:
#              :-) GROMACS - gmx solvate, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx solvate, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx solvate -cp pocket_box.gro -cs spc216.gro -o solvated_pocket.gro -p topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x3 boxes
# Solvent box contains 8673 atoms in 2891 residues
# Removed 1842 solvent atoms due to solvent-solvent overlap
# Removed 144 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  2229 residues
# Generated solvent containing 6687 atoms in 2229 residues
# Writing generated configuration to solvated_pocket.gro
#
# Output configuration contains 6838 atoms in 2238 residues
# Volume                 :     69.5645 (nm^3)
# Density                :     985.258 (g/l)
# Number of solvent molecules:   2229
#
# Processing topology
# Adding line for 2229 solvent molecules with resname (SOL) to topology file (topol.top)
#
# Back Off! I just backed up topol.top to ./#topol.top.1#
#
# GROMACS reminds you: "I cannot think of a single one, not even intelligence." (Enrico Fermi, when asked what characteristics physics Nobel laureates had in common.)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f ions.mdp -c solvated_pocket.gro -p topol.top -o ions.tpr
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f ions.mdp -c solvated_pocket.gro -p topol.top -o ions.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file ions.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -44048525
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 13824.00
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.114 0.114 0.114
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 1 Mb of data
#
# There was 1 note
#
# GROMACS reminds you: "Weaseling out of things is important to learn. It's what separates us from the animals... except the weasels." (Homer Simpson)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !echo 13 | gmx genion -s ions.tpr -o neutralized_pocket.gro -p topol.top -pname NA -nname CL -neutral
# Out:
#               :-) GROMACS - gmx genion, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx genion, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx genion -s ions.tpr -o neutralized_pocket.gro -p topol.top -pname NA -nname CL -neutral
#
# Reading file ions.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file ions.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# No ions to add, will just copy input configuration.
#
# GROMACS reminds you: "Though the path of the comet is sure, it's constitution is not" (Peter Hammill)

# %% [markdown]
# ### Save analysis results or plots to file.

# %%
mdp_content = """; Energy minimization parameters
integrator    = steep
emtol         = 1000.0
emstep        = 0.01
nsteps        = 50000
nstlist       = 1
cutoff-scheme = Verlet
ns_type       = grid
coulombtype   = PME
rcoulomb      = 1.0
rvdw          = 1.0
pbc           = xyz
"""

file_path = "/content/drive/MyDrive/Rayca_eval/MD_simulation/em.mdp"

# Save the .mdp file
with open(file_path, "w") as f:
    f.write(mdp_content)

print(f"Saved em.mdp to {file_path}")
# Out:
# Saved em.mdp to /content/drive/MyDrive/Rayca_eval/MD_simulation/em.mdp

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f /content/drive/MyDrive/Rayca_eval/MD_simulation/em.mdp \
           -c /content/drive/MyDrive/Rayca_eval/MD_simulation/neutralized_pocket.gro \
           -p /content/drive/MyDrive/Rayca_eval/MD_simulation/topol.top \
           -o /content/drive/MyDrive/Rayca_eval/MD_simulation/em.tpr
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f /content/drive/MyDrive/Rayca_eval/MD_simulation/em.mdp -c /content/drive/MyDrive/Rayca_eval/MD_simulation/neutralized_pocket.gro -p /content/drive/MyDrive/Rayca_eval/MD_simulation/topol.top -o /content/drive/MyDrive/Rayca_eval/MD_simulation/em.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file /content/drive/MyDrive/Rayca_eval/MD_simulation/em.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -201853185
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 13824.00
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.114 0.114 0.114
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 1 Mb of data
#
# There was 1 note
#
# GROMACS reminds you: "The way to succeed is to double your failure rate." (Thomas J. Watson)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx mdrun -v -deffnm /content/drive/MyDrive/Rayca_eval/MD_simulation/em
# Out:
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -v -deffnm /content/drive/MyDrive/Rayca_eval/MD_simulation/em
#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file /content/drive/MyDrive/Rayca_eval/MD_simulation/em.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =        50000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  1.51249e+05 Fmax= 2.80235e+05, atom= 123
# Step=    1, Dmax= 1.0e-02 nm, Epot=  1.33341e+05 Fmax= 2.70525e+05, atom= 123
# Step=    2, Dmax= 1.2e-02 nm, Epot=  1.15641e+05 Fmax= 2.58758e+05, atom= 123
# Step=    3, Dmax= 1.4e-02 nm, Epot=  9.73602e+04 Fmax= 2.44205e+05, atom= 123
# Step=    4, Dmax= 1.7e-02 nm, Epot=  7.82827e+04 Fmax= 2.25749e+05, atom= 123
# Step=    5, Dmax= 2.1e-02 nm, Epot=  5.84859e+04 Fmax= 2.01723e+05, atom= 123
# Step=    6, Dmax= 2.5e-02 nm, Epot=  3.83130e+04 Fmax= 1.68504e+05, atom= 123
# Step=    7, Dmax= 3.0e-02 nm, Epot=  1.83793e+04 Fmax= 1.24699e+05, atom= 125
# Step=    8, Dmax= 3.6e-02 nm, Epot= -4.77832e+01 Fmax= 9.71601e+04, atom= 118
# Step=    9, Dmax= 4.3e-02 nm, Epot= -1.37130e+04 Fmax= 1.22254e+05, atom= 118
# Step=   10, Dmax= 5.2e-02 nm, Epot= -2.21221e+04 Fmax= 4.65922e+05, atom= 118
# Step=   11, Dmax= 6.2e-02 nm, Epot= -2.57348e+04 Fmax= 1.28029e+05, atom= 123
# Step=   12, Dmax= 7.4e-02 nm, Epot= -3.85895e+04 Fmax= 9.08264e+04, atom= 123
# Step=   13, Dmax= 8.9e-02 nm, Epot= -4.58646e+04 Fmax= 1.86983e+05, atom= 123
#
# step 14: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
# Wrote pdb files with previous and current coordinates
# Step=   15, Dmax= 5.3e-02 nm, Epot= -5.30074e+04 Fmax= 4.10912e+04, atom= 123
# Step=   16, Dmax= 6.4e-02 nm, Epot= -6.26564e+04 Fmax= 1.04630e+05, atom= 123
# Step=   17, Dmax= 7.7e-02 nm, Epot= -6.51139e+04 Fmax= 6.37031e+04, atom= 123
# Step=   18, Dmax= 9.2e-02 nm, Epot= -6.99419e+04 Fmax= 5.17883e+04, atom= 123
# Step=   20, Dmax= 5.5e-02 nm, Epot= -7.29888e+04 Fmax= 4.67681e+04, atom= 123
# Step=   21, Dmax= 6.7e-02 nm, Epot= -7.53197e+04 Fmax= 4.44560e+04, atom= 123
# Step=   23, Dmax= 4.0e-02 nm, Epot= -7.79005e+04 Fmax= 2.80959e+04, atom= 123
# Step=   24, Dmax= 4.8e-02 nm, Epot= -7.94528e+04 Fmax= 4.51941e+04, atom= 123
# Step=   25, Dmax= 5.8e-02 nm, Epot= -8.03683e+04 Fmax= 5.61424e+04, atom= 123
# Step=   26, Dmax= 6.9e-02 nm, Epot= -8.18078e+04 Fmax= 5.01270e+04, atom= 123
# Step=   28, Dmax= 4.1e-02 nm, Epot= -8.35989e+04 Fmax= 2.29298e+04, atom= 123
# Step=   29, Dmax= 5.0e-02 nm, Epot= -8.42896e+04 Fmax= 5.72306e+04, atom= 123
# Step=   30, Dmax= 6.0e-02 nm, Epot= -8.53136e+04 Fmax= 4.21756e+04, atom= 123
# Step=   31, Dmax= 7.2e-02 nm, Epot= -8.53348e+04 Fmax= 6.98381e+04, atom= 123
# Step=   32, Dmax= 8.6e-02 nm, Epot= -8.57565e+04 Fmax= 6.29188e+04, atom= 123
# Step=   34, Dmax= 5.2e-02 nm, Epot= -8.82395e+04 Fmax= 1.12253e+04, atom= 123
# Step=   36, Dmax= 3.1e-02 nm, Epot= -8.91119e+04 Fmax= 3.04476e+04, atom= 123
# Step=   37, Dmax= 3.7e-02 nm, Epot= -8.99596e+04 Fmax= 1.92440e+04, atom= 123
# Step=   39, Dmax= 2.2e-02 nm, Epot= -9.05819e+04 Fmax= 1.57506e+04, atom= 123
# Step=   40, Dmax= 2.7e-02 nm, Epot= -9.10741e+04 Fmax= 2.05651e+04, atom= 123
# Step=   41, Dmax= 3.2e-02 nm, Epot= -9.14514e+04 Fmax= 2.77698e+04, atom= 123
# Step=   42, Dmax= 3.8e-02 nm, Epot= -9.19312e+04 Fmax= 2.62193e+04, atom= 123
# Step=   44, Dmax= 2.3e-02 nm, Epot= -9.26027e+04 Fmax= 8.41558e+03, atom= 123
# Step=   45, Dmax= 2.8e-02 nm, Epot= -9.31450e+04 Fmax= 2.84021e+04, atom= 123
# Step=   46, Dmax= 3.3e-02 nm, Epot= -9.37020e+04 Fmax= 1.99017e+04, atom= 123
# Step=   48, Dmax= 2.0e-02 nm, Epot= -9.41463e+04 Fmax= 7.22427e+03, atom= 123
# Step=   49, Dmax= 2.4e-02 nm, Epot= -9.45044e+04 Fmax= 2.84603e+04, atom= 123
# Step=   50, Dmax= 2.9e-02 nm, Epot= -9.51434e+04 Fmax= 1.09769e+04, atom= 123
# Step=   52, Dmax= 1.7e-02 nm, Epot= -9.54508e+04 Fmax= 1.40218e+04, atom= 123
# Step=   53, Dmax= 2.1e-02 nm, Epot= -9.57468e+04 Fmax= 1.39376e+04, atom= 123
# Step=   54, Dmax= 2.5e-02 nm, Epot= -9.59456e+04 Fmax= 2.12529e+04, atom= 123
# Step=   55, Dmax= 3.0e-02 nm, Epot= -9.62466e+04 Fmax= 1.92762e+04, atom= 123
# Step=   57, Dmax= 1.8e-02 nm, Epot= -9.66556e+04 Fmax= 6.02084e+03, atom= 123
# Step=   58, Dmax= 2.1e-02 nm, Epot= -9.69555e+04 Fmax= 2.17972e+04, atom= 123
# Step=   59, Dmax= 2.6e-02 nm, Epot= -9.73555e+04 Fmax= 1.39623e+04, atom= 123
# Step=   61, Dmax= 1.5e-02 nm, Epot= -9.76429e+04 Fmax= 6.61056e+03, atom= 123
# Step=   62, Dmax= 1.9e-02 nm, Epot= -9.76992e+04 Fmax= 1.96771e+04, atom= 123
# Step=   63, Dmax= 2.2e-02 nm, Epot= -9.81326e+04 Fmax= 1.25771e+04, atom= 132
# Step=   65, Dmax= 1.3e-02 nm, Epot= -9.84030e+04 Fmax= 7.22798e+03, atom= 132
# Step=   66, Dmax= 1.6e-02 nm, Epot= -9.85185e+04 Fmax= 1.76176e+04, atom= 132
# Step=   67, Dmax= 1.9e-02 nm, Epot= -9.88180e+04 Fmax= 1.10454e+04, atom= 132
# Step=   69, Dmax= 1.2e-02 nm, Epot= -9.90194e+04 Fmax= 6.64756e+03, atom= 132
# Step=   70, Dmax= 1.4e-02 nm, Epot= -9.91855e+04 Fmax= 1.36750e+04, atom= 132
# Step=   71, Dmax= 1.7e-02 nm, Epot= -9.93769e+04 Fmax= 1.16769e+04, atom= 132
# Step=   72, Dmax= 2.0e-02 nm, Epot= -9.94484e+04 Fmax= 1.79522e+04, atom= 132
# Step=   73, Dmax= 2.4e-02 nm, Epot= -9.95982e+04 Fmax= 1.83150e+04, atom= 132
# Step=   75, Dmax= 1.4e-02 nm, Epot= -9.99139e+04 Fmax= 3.06782e+03, atom= 132
# Step=   76, Dmax= 1.7e-02 nm, Epot= -1.00091e+05 Fmax= 2.42647e+04, atom= 132
# Step=   77, Dmax= 2.1e-02 nm, Epot= -1.00593e+05 Fmax= 6.80341e+03, atom= 132
# Step=   79, Dmax= 1.2e-02 nm, Epot= -1.00690e+05 Fmax= 1.22145e+04, atom= 132
# Step=   80, Dmax= 1.5e-02 nm, Epot= -1.00843e+05 Fmax= 1.00215e+04, atom= 132
# Step=   82, Dmax= 8.9e-03 nm, Epot= -1.01012e+05 Fmax= 3.58192e+03, atom= 132
# Step=   83, Dmax= 1.1e-02 nm, Epot= -1.01152e+05 Fmax= 1.26268e+04, atom= 149
# Step=   84, Dmax= 1.3e-02 nm, Epot= -1.01351e+05 Fmax= 7.28135e+03, atom= 149
# Step=   86, Dmax= 7.7e-03 nm, Epot= -1.01475e+05 Fmax= 4.61285e+03, atom= 149
# Step=   87, Dmax= 9.2e-03 nm, Epot= -1.01591e+05 Fmax= 9.76101e+03, atom= 149
# Step=   88, Dmax= 1.1e-02 nm, Epot= -1.01724e+05 Fmax= 7.37444e+03, atom= 149
# Step=   89, Dmax= 1.3e-02 nm, Epot= -1.01783e+05 Fmax= 1.32919e+04, atom= 149
# Step=   90, Dmax= 1.6e-02 nm, Epot= -1.01921e+05 Fmax= 1.13699e+04, atom= 149
# Step=   92, Dmax= 9.6e-03 nm, Epot= -1.02078e+05 Fmax= 3.49124e+03, atom= 149
# Step=   93, Dmax= 1.1e-02 nm, Epot= -1.02210e+05 Fmax= 1.41583e+04, atom= 149
# Step=   94, Dmax= 1.4e-02 nm, Epot= -1.02388e+05 Fmax= 7.24929e+03, atom= 149
# Step=   96, Dmax= 8.3e-03 nm, Epot= -1.02489e+05 Fmax= 5.50674e+03, atom= 149
# Step=   97, Dmax= 9.9e-03 nm, Epot= -1.02580e+05 Fmax= 9.96317e+03, atom= 149
# Step=   98, Dmax= 1.2e-02 nm, Epot= -1.02685e+05 Fmax= 8.42403e+03, atom= 149
# Step=   99, Dmax= 1.4e-02 nm, Epot= -1.02736e+05 Fmax= 1.38038e+04, atom= 149
# Step=  100, Dmax= 1.7e-02 nm, Epot= -1.02842e+05 Fmax= 1.26671e+04, atom= 149
# Step=  102, Dmax= 1.0e-02 nm, Epot= -1.02989e+05 Fmax= 3.31014e+03, atom= 149
# Step=  103, Dmax= 1.2e-02 nm, Epot= -1.03109e+05 Fmax= 1.55780e+04, atom= 149
# Step=  104, Dmax= 1.5e-02 nm, Epot= -1.03280e+05 Fmax= 7.44165e+03, atom= 149
# Step=  106, Dmax= 8.9e-03 nm, Epot= -1.03367e+05 Fmax= 6.24425e+03, atom= 149
# Step=  107, Dmax= 1.1e-02 nm, Epot= -1.03439e+05 Fmax= 1.03993e+04, atom= 149
# Step=  108, Dmax= 1.3e-02 nm, Epot= -1.03527e+05 Fmax= 9.33714e+03, atom= 149
# Step=  109, Dmax= 1.5e-02 nm, Epot= -1.03563e+05 Fmax= 1.45645e+04, atom= 149
# Step=  110, Dmax= 1.8e-02 nm, Epot= -1.03650e+05 Fmax= 1.38541e+04, atom= 149
# Step=  112, Dmax= 1.1e-02 nm, Epot= -1.03796e+05 Fmax= 3.31980e+03, atom= 149
# Step=  113, Dmax= 1.3e-02 nm, Epot= -1.03887e+05 Fmax= 1.69129e+04, atom= 149
# Step=  114, Dmax= 1.6e-02 nm, Epot= -1.04060e+05 Fmax= 7.83508e+03, atom= 149
# Step=  116, Dmax= 9.6e-03 nm, Epot= -1.04136e+05 Fmax= 6.85548e+03, atom= 149
# Step=  117, Dmax= 1.1e-02 nm, Epot= -1.04192e+05 Fmax= 1.10433e+04, atom= 149
# Step=  118, Dmax= 1.4e-02 nm, Epot= -1.04269e+05 Fmax= 1.01487e+04, atom= 149
# Step=  119, Dmax= 1.7e-02 nm, Epot= -1.04287e+05 Fmax= 1.55450e+04, atom= 149
# Step=  120, Dmax= 2.0e-02 nm, Epot= -1.04362e+05 Fmax= 1.49714e+04, atom= 149
# Step=  122, Dmax= 1.2e-02 nm, Epot= -1.04514e+05 Fmax= 3.48394e+03, atom= 149
# Step=  123, Dmax= 1.4e-02 nm, Epot= -1.04564e+05 Fmax= 1.82202e+04, atom= 149
# Step=  124, Dmax= 1.7e-02 nm, Epot= -1.04746e+05 Fmax= 8.37917e+03, atom= 149
# Step=  126, Dmax= 1.0e-02 nm, Epot= -1.04814e+05 Fmax= 7.39712e+03, atom= 149
# Step=  127, Dmax= 1.2e-02 nm, Epot= -1.04854e+05 Fmax= 1.18444e+04, atom= 149
# Step=  128, Dmax= 1.5e-02 nm, Epot= -1.04924e+05 Fmax= 1.09179e+04, atom= 149
# Step=  130, Dmax= 8.9e-03 nm, Epot= -1.05020e+05 Fmax= 2.89757e+03, atom= 149
# Step=  131, Dmax= 1.1e-02 nm, Epot= -1.05110e+05 Fmax= 1.32208e+04, atom= 149
# Step=  132, Dmax= 1.3e-02 nm, Epot= -1.05221e+05 Fmax= 6.67118e+03, atom= 149
# Step=  134, Dmax= 7.7e-03 nm, Epot= -1.05282e+05 Fmax= 5.08165e+03, atom= 149
# Step=  135, Dmax= 9.2e-03 nm, Epot= -1.05334e+05 Fmax= 9.35636e+03, atom= 149
# Step=  136, Dmax= 1.1e-02 nm, Epot= -1.05400e+05 Fmax= 7.61552e+03, atom= 149
# Step=  137, Dmax= 1.3e-02 nm, Epot= -1.05422e+05 Fmax= 1.30794e+04, atom= 149
# Step=  138, Dmax= 1.6e-02 nm, Epot= -1.05494e+05 Fmax= 1.13879e+04, atom= 149
# Step=  140, Dmax= 9.6e-03 nm, Epot= -1.05590e+05 Fmax= 3.46111e+03, atom= 149
# Step=  141, Dmax= 1.1e-02 nm, Epot= -1.05640e+05 Fmax= 1.39024e+04, atom= 149
# Step=  142, Dmax= 1.4e-02 nm, Epot= -1.05751e+05 Fmax= 7.47284e+03, atom= 149
# Step=  144, Dmax= 8.3e-03 nm, Epot= -1.05810e+05 Fmax= 5.16271e+03, atom= 149
# Step=  145, Dmax= 9.9e-03 nm, Epot= -1.05850e+05 Fmax= 1.03614e+04, atom= 149
# Step=  146, Dmax= 1.2e-02 nm, Epot= -1.05917e+05 Fmax= 7.88274e+03, atom= 149
# Step=  147, Dmax= 1.4e-02 nm, Epot= -1.05919e+05 Fmax= 1.43597e+04, atom= 149
# Step=  148, Dmax= 1.7e-02 nm, Epot= -1.05996e+05 Fmax= 1.19356e+04, atom= 149
# Step=  150, Dmax= 1.0e-02 nm, Epot= -1.06093e+05 Fmax= 4.01880e+03, atom= 149
# Step=  151, Dmax= 1.2e-02 nm, Epot= -1.06112e+05 Fmax= 1.46775e+04, atom= 149
# Step=  152, Dmax= 1.5e-02 nm, Epot= -1.06224e+05 Fmax= 8.28784e+03, atom= 149
# Step=  154, Dmax= 8.9e-03 nm, Epot= -1.06284e+05 Fmax= 5.29717e+03, atom= 149
# Step=  155, Dmax= 1.1e-02 nm, Epot= -1.06310e+05 Fmax= 1.13880e+04, atom= 149
# Step=  156, Dmax= 1.3e-02 nm, Epot= -1.06380e+05 Fmax= 8.22452e+03, atom= 149
# Step=  158, Dmax= 7.7e-03 nm, Epot= -1.06442e+05 Fmax= 3.72806e+03, atom= 149
# Step=  159, Dmax= 9.2e-03 nm, Epot= -1.06485e+05 Fmax= 1.02054e+04, atom= 149
# Step=  160, Dmax= 1.1e-02 nm, Epot= -1.06552e+05 Fmax= 6.98350e+03, atom= 149
# Step=  161, Dmax= 1.3e-02 nm, Epot= -1.06555e+05 Fmax= 1.32606e+04, atom= 149
# Step=  162, Dmax= 1.6e-02 nm, Epot= -1.06621e+05 Fmax= 1.14298e+04, atom= 149
# Step=  164, Dmax= 9.5e-03 nm, Epot= -1.06708e+05 Fmax= 3.20483e+03, atom= 149
# Step=  165, Dmax= 1.1e-02 nm, Epot= -1.06727e+05 Fmax= 1.49030e+04, atom= 149
# Step=  166, Dmax= 1.4e-02 nm, Epot= -1.06847e+05 Fmax= 6.21960e+03, atom= 149
# Step=  168, Dmax= 8.2e-03 nm, Epot= -1.06889e+05 Fmax= 6.66936e+03, atom= 149
# Step=  169, Dmax= 9.9e-03 nm, Epot= -1.06923e+05 Fmax= 8.43816e+03, atom= 149
# Step=  170, Dmax= 1.2e-02 nm, Epot= -1.06956e+05 Fmax= 1.00634e+04, atom= 149
# Step=  171, Dmax= 1.4e-02 nm, Epot= -1.06982e+05 Fmax= 1.17610e+04, atom= 149
# Step=  172, Dmax= 1.7e-02 nm, Epot= -1.06990e+05 Fmax= 1.47893e+04, atom= 149
# Step=  173, Dmax= 2.1e-02 nm, Epot= -1.07002e+05 Fmax= 1.66643e+04, atom= 149
# Step=  175, Dmax= 1.2e-02 nm, Epot= -1.07162e+05 Fmax= 2.40583e+03, atom= 149
# Step=  176, Dmax= 1.5e-02 nm, Epot= -1.07163e+05 Fmax= 1.96706e+04, atom= 149
# Step=  177, Dmax= 1.8e-02 nm, Epot= -1.07352e+05 Fmax= 7.84461e+03, atom= 149
# Step=  179, Dmax= 1.1e-02 nm, Epot= -1.07387e+05 Fmax= 8.41309e+03, atom= 149
# Step=  180, Dmax= 1.3e-02 nm, Epot= -1.07403e+05 Fmax= 1.14759e+04, atom= 149
# Step=  181, Dmax= 1.5e-02 nm, Epot= -1.07434e+05 Fmax= 1.19935e+04, atom= 149
# Step=  183, Dmax= 9.2e-03 nm, Epot= -1.07526e+05 Fmax= 2.28185e+03, atom= 149
# Step=  184, Dmax= 1.1e-02 nm, Epot= -1.07568e+05 Fmax= 1.41673e+04, atom= 149
# Step=  185, Dmax= 1.3e-02 nm, Epot= -1.07674e+05 Fmax= 6.38940e+03, atom= 149
# Step=  187, Dmax= 7.9e-03 nm, Epot= -1.07712e+05 Fmax= 5.72163e+03, atom= 149
# Step=  188, Dmax= 9.5e-03 nm, Epot= -1.07734e+05 Fmax= 9.19300e+03, atom= 149
# Step=  189, Dmax= 1.1e-02 nm, Epot= -1.07774e+05 Fmax= 8.30975e+03, atom= 149
# Step=  191, Dmax= 6.9e-03 nm, Epot= -1.07828e+05 Fmax= 2.38137e+03, atom= 149
# Step=  192, Dmax= 8.2e-03 nm, Epot= -1.07875e+05 Fmax= 9.92098e+03, atom= 149
# Step=  193, Dmax= 9.9e-03 nm, Epot= -1.07936e+05 Fmax= 5.45683e+03, atom= 149
# Step=  195, Dmax= 5.9e-03 nm, Epot= -1.07973e+05 Fmax= 3.56828e+03, atom= 149
# Step=  196, Dmax= 7.1e-03 nm, Epot= -1.08003e+05 Fmax= 7.65568e+03, atom= 149
# Step=  197, Dmax= 8.5e-03 nm, Epot= -1.08045e+05 Fmax= 5.39518e+03, atom= 149
# Step=  198, Dmax= 1.0e-02 nm, Epot= -1.08054e+05 Fmax= 1.06477e+04, atom= 149
# Step=  199, Dmax= 1.2e-02 nm, Epot= -1.08104e+05 Fmax= 8.18979e+03, atom= 149
# Step=  201, Dmax= 7.4e-03 nm, Epot= -1.08156e+05 Fmax= 3.30009e+03, atom= 149
# Step=  202, Dmax= 8.8e-03 nm, Epot= -1.08178e+05 Fmax= 1.00504e+04, atom= 149
# Step=  203, Dmax= 1.1e-02 nm, Epot= -1.08234e+05 Fmax= 6.47108e+03, atom= 149
# Step=  205, Dmax= 6.4e-03 nm, Epot= -1.08273e+05 Fmax= 3.25196e+03, atom= 149
# Step=  206, Dmax= 7.6e-03 nm, Epot= -1.08298e+05 Fmax= 8.83137e+03, atom= 149
# Step=  207, Dmax= 9.2e-03 nm, Epot= -1.08347e+05 Fmax= 5.21701e+03, atom= 149
# Step=  209, Dmax= 5.5e-03 nm, Epot= -1.08381e+05 Fmax= 3.40653e+03, atom= 149
# Step=  210, Dmax= 6.6e-03 nm, Epot= -1.08410e+05 Fmax= 6.57165e+03, atom= 149
# Step=  211, Dmax= 7.9e-03 nm, Epot= -1.08444e+05 Fmax= 5.81097e+03, atom= 149
# Step=  212, Dmax= 9.5e-03 nm, Epot= -1.08461e+05 Fmax= 8.68824e+03, atom= 149
# Step=  213, Dmax= 1.1e-02 nm, Epot= -1.08489e+05 Fmax= 9.08635e+03, atom= 149
# Step=  214, Dmax= 1.4e-02 nm, Epot= -1.08494e+05 Fmax= 1.18765e+04, atom= 149
# Step=  215, Dmax= 1.6e-02 nm, Epot= -1.08505e+05 Fmax= 1.36350e+04, atom= 149
# Step=  217, Dmax= 9.9e-03 nm, Epot= -1.08611e+05 Fmax= 1.50419e+03, atom= 149
# Step=  218, Dmax= 1.2e-02 nm, Epot= -1.08636e+05 Fmax= 1.76539e+04, atom= 149
# Step=  219, Dmax= 1.4e-02 nm, Epot= -1.08797e+05 Fmax= 4.23296e+03, atom= 149
# Step=  221, Dmax= 8.5e-03 nm, Epot= -1.08808e+05 Fmax= 9.15570e+03, atom= 149
# Step=  222, Dmax= 1.0e-02 nm, Epot= -1.08851e+05 Fmax= 6.51253e+03, atom= 149
# Step=  224, Dmax= 6.1e-03 nm, Epot= -1.08888e+05 Fmax= 3.06492e+03, atom= 149
# Step=  225, Dmax= 7.4e-03 nm, Epot= -1.08911e+05 Fmax= 8.04081e+03, atom= 149
# Step=  226, Dmax= 8.8e-03 nm, Epot= -1.08950e+05 Fmax= 5.72286e+03, atom= 149
# Step=  228, Dmax= 5.3e-03 nm, Epot= -1.08982e+05 Fmax= 2.36130e+03, atom= 149
# Step=  229, Dmax= 6.4e-03 nm, Epot= -1.09012e+05 Fmax= 7.75897e+03, atom= 149
# Step=  230, Dmax= 7.6e-03 nm, Epot= -1.09053e+05 Fmax= 3.92250e+03, atom= 149
# Step=  231, Dmax= 9.2e-03 nm, Epot= -1.09055e+05 Fmax= 1.04790e+04, atom= 149
# Step=  232, Dmax= 1.1e-02 nm, Epot= -1.09109e+05 Fmax= 6.37612e+03, atom= 149
# Step=  234, Dmax= 6.6e-03 nm, Epot= -1.09142e+05 Fmax= 3.91675e+03, atom= 149
# Step=  235, Dmax= 7.9e-03 nm, Epot= -1.09157e+05 Fmax= 8.08363e+03, atom= 149
# Step=  236, Dmax= 9.5e-03 nm, Epot= -1.09191e+05 Fmax= 6.70485e+03, atom= 149
# Step=  238, Dmax= 5.7e-03 nm, Epot= -1.09227e+05 Fmax= 2.00162e+03, atom= 149
# Step=  239, Dmax= 6.8e-03 nm, Epot= -1.09257e+05 Fmax= 8.92553e+03, atom= 149
# Step=  240, Dmax= 8.2e-03 nm, Epot= -1.09306e+05 Fmax= 3.64916e+03, atom= 149
# Step=  242, Dmax= 4.9e-03 nm, Epot= -1.09331e+05 Fmax= 4.09689e+03, atom= 149
# Step=  243, Dmax= 5.9e-03 nm, Epot= -1.09354e+05 Fmax= 4.87389e+03, atom= 149
# Step=  244, Dmax= 7.1e-03 nm, Epot= -1.09374e+05 Fmax= 6.22801e+03, atom= 149
# Step=  245, Dmax= 8.5e-03 nm, Epot= -1.09396e+05 Fmax= 6.76271e+03, atom= 149
# Step=  246, Dmax= 1.0e-02 nm, Epot= -1.09406e+05 Fmax= 9.15600e+03, atom= 149
# Step=  247, Dmax= 1.2e-02 nm, Epot= -1.09425e+05 Fmax= 9.60705e+03, atom= 149
# Step=  249, Dmax= 7.3e-03 nm, Epot= -1.09484e+05 Fmax= 1.81571e+03, atom= 149
# Step=  250, Dmax= 8.8e-03 nm, Epot= -1.09510e+05 Fmax= 1.13023e+04, atom= 149
# Step=  251, Dmax= 1.1e-02 nm, Epot= -1.09577e+05 Fmax= 5.13995e+03, atom= 149
# Step=  253, Dmax= 6.3e-03 nm, Epot= -1.09601e+05 Fmax= 4.53733e+03, atom= 149
# Step=  254, Dmax= 7.6e-03 nm, Epot= -1.09615e+05 Fmax= 7.40107e+03, atom= 149
# Step=  255, Dmax= 9.1e-03 nm, Epot= -1.09641e+05 Fmax= 6.58912e+03, atom= 149
# Step=  257, Dmax= 5.5e-03 nm, Epot= -1.09676e+05 Fmax= 1.96554e+03, atom= 149
# Step=  258, Dmax= 6.6e-03 nm, Epot= -1.09705e+05 Fmax= 7.86282e+03, atom= 149
# Step=  259, Dmax= 7.9e-03 nm, Epot= -1.09743e+05 Fmax= 4.43861e+03, atom= 149
# Step=  261, Dmax= 4.7e-03 nm, Epot= -1.09767e+05 Fmax= 2.77398e+03, atom= 149
# Step=  262, Dmax= 5.7e-03 nm, Epot= -1.09787e+05 Fmax= 6.21599e+03, atom= 149
# Step=  263, Dmax= 6.8e-03 nm, Epot= -1.09815e+05 Fmax= 4.21526e+03, atom= 149
# Step=  264, Dmax= 8.2e-03 nm, Epot= -1.09821e+05 Fmax= 8.62646e+03, atom= 149
# Step=  265, Dmax= 9.8e-03 nm, Epot= -1.09855e+05 Fmax= 6.43461e+03, atom= 149
# Step=  267, Dmax= 5.9e-03 nm, Epot= -1.09887e+05 Fmax= 2.75942e+03, atom= 149
# Step=  268, Dmax= 7.1e-03 nm, Epot= -1.09902e+05 Fmax= 7.91676e+03, atom= 149
# Step=  269, Dmax= 8.5e-03 nm, Epot= -1.09937e+05 Fmax= 5.29963e+03, atom= 149
# Step=  271, Dmax= 5.1e-03 nm, Epot= -1.09963e+05 Fmax= 2.47434e+03, atom= 149
# Step=  272, Dmax= 6.1e-03 nm, Epot= -1.09981e+05 Fmax= 7.20722e+03, atom= 149
# Step=  273, Dmax= 7.3e-03 nm, Epot= -1.10014e+05 Fmax= 4.02486e+03, atom= 149
# Step=  275, Dmax= 4.4e-03 nm, Epot= -1.10036e+05 Fmax= 2.87769e+03, atom= 149
# Step=  276, Dmax= 5.3e-03 nm, Epot= -1.10056e+05 Fmax= 5.10503e+03, atom= 149
# Step=  277, Dmax= 6.3e-03 nm, Epot= -1.10077e+05 Fmax= 4.80243e+03, atom= 149
# Step=  278, Dmax= 7.6e-03 nm, Epot= -1.10090e+05 Fmax= 6.79277e+03, atom= 149
# Step=  279, Dmax= 9.1e-03 nm, Epot= -1.10107e+05 Fmax= 7.42740e+03, atom= 149
# Step=  280, Dmax= 1.1e-02 nm, Epot= -1.10113e+05 Fmax= 9.33939e+03, atom= 149
# Step=  281, Dmax= 1.3e-02 nm, Epot= -1.10119e+05 Fmax= 1.10745e+04, atom= 149
# Step=  283, Dmax= 7.9e-03 nm, Epot= -1.10189e+05 Fmax= 1.03364e+03, atom= 149
# Step=  284, Dmax= 9.5e-03 nm, Epot= -1.10227e+05 Fmax= 1.44298e+04, atom= 149
# Step=  285, Dmax= 1.1e-02 nm, Epot= -1.10335e+05 Fmax= 3.06785e+03, atom= 149
# Step=  287, Dmax= 6.8e-03 nm, Epot= -1.10344e+05 Fmax= 7.65657e+03, atom= 149
# Step=  288, Dmax= 8.2e-03 nm, Epot= -1.10376e+05 Fmax= 4.87596e+03, atom= 149
# Step=  290, Dmax= 4.9e-03 nm, Epot= -1.10399e+05 Fmax= 2.78919e+03, atom= 149
# Step=  291, Dmax= 5.9e-03 nm, Epot= -1.10414e+05 Fmax= 6.11593e+03, atom= 149
# Step=  292, Dmax= 7.1e-03 nm, Epot= -1.10438e+05 Fmax= 4.89479e+03, atom= 149
# Step=  293, Dmax= 8.5e-03 nm, Epot= -1.10442e+05 Fmax= 8.04101e+03, atom= 149
# Step=  294, Dmax= 1.0e-02 nm, Epot= -1.10463e+05 Fmax= 7.77289e+03, atom= 149
# Step=  296, Dmax= 6.1e-03 nm, Epot= -1.10502e+05 Fmax= 1.58141e+03, atom= 149
# Step=  297, Dmax= 7.3e-03 nm, Epot= -1.10519e+05 Fmax= 1.01349e+04, atom= 149
# Step=  298, Dmax= 8.8e-03 nm, Epot= -1.10575e+05 Fmax= 3.36604e+03, atom= 149
# Step=  300, Dmax= 5.3e-03 nm, Epot= -1.10591e+05 Fmax= 4.91148e+03, atom= 149
# Step=  301, Dmax= 6.3e-03 nm, Epot= -1.10609e+05 Fmax= 4.75024e+03, atom= 149
# Step=  302, Dmax= 7.6e-03 nm, Epot= -1.10618e+05 Fmax= 7.11080e+03, atom= 149
# Step=  303, Dmax= 9.1e-03 nm, Epot= -1.10636e+05 Fmax= 6.84758e+03, atom= 149
# Step=  305, Dmax= 5.5e-03 nm, Epot= -1.10669e+05 Fmax= 1.65917e+03, atom= 149
# Step=  306, Dmax= 6.6e-03 nm, Epot= -1.10691e+05 Fmax= 8.14363e+03, atom= 149
# Step=  307, Dmax= 7.9e-03 nm, Epot= -1.10729e+05 Fmax= 4.09402e+03, atom= 149
# Step=  309, Dmax= 4.7e-03 nm, Epot= -1.10747e+05 Fmax= 3.10464e+03, atom= 149
# Step=  310, Dmax= 5.7e-03 nm, Epot= -1.10760e+05 Fmax= 5.79898e+03, atom= 149
# Step=  311, Dmax= 6.8e-03 nm, Epot= -1.10781e+05 Fmax= 4.60754e+03, atom= 149
# Step=  312, Dmax= 8.2e-03 nm, Epot= -1.10783e+05 Fmax= 8.14040e+03, atom= 149
# Step=  313, Dmax= 9.8e-03 nm, Epot= -1.10807e+05 Fmax= 6.88061e+03, atom= 149
# Step=  315, Dmax= 5.9e-03 nm, Epot= -1.10840e+05 Fmax= 2.25939e+03, atom= 149
# Step=  316, Dmax= 7.0e-03 nm, Epot= -1.10848e+05 Fmax= 8.37945e+03, atom= 149
# Step=  317, Dmax= 8.5e-03 nm, Epot= -1.10885e+05 Fmax= 4.76685e+03, atom= 149
# Step=  319, Dmax= 5.1e-03 nm, Epot= -1.10905e+05 Fmax= 2.98767e+03, atom= 149
# Step=  320, Dmax= 6.1e-03 nm, Epot= -1.10914e+05 Fmax= 6.58220e+03, atom= 149
# Step=  321, Dmax= 7.3e-03 nm, Epot= -1.10939e+05 Fmax= 4.61882e+03, atom= 149
# Step=  323, Dmax= 4.4e-03 nm, Epot= -1.10959e+05 Fmax= 2.22857e+03, atom= 149
# Step=  324, Dmax= 5.3e-03 nm, Epot= -1.10975e+05 Fmax= 5.71588e+03, atom= 149
# Step=  325, Dmax= 6.3e-03 nm, Epot= -1.10997e+05 Fmax= 4.12442e+03, atom= 149
# Step=  326, Dmax= 7.6e-03 nm, Epot= -1.11000e+05 Fmax= 7.43690e+03, atom= 149
# Step=  327, Dmax= 9.1e-03 nm, Epot= -1.11021e+05 Fmax= 6.70014e+03, atom= 149
# Step=  329, Dmax= 5.5e-03 nm, Epot= -1.11052e+05 Fmax= 1.66369e+03, atom= 149
# Step=  330, Dmax= 6.5e-03 nm, Epot= -1.11064e+05 Fmax= 8.75292e+03, atom= 149
# Step=  331, Dmax= 7.9e-03 nm, Epot= -1.11107e+05 Fmax= 3.31663e+03, atom= 149
# Step=  333, Dmax= 4.7e-03 nm, Epot= -1.11122e+05 Fmax= 4.07171e+03, atom= 149
# Step=  334, Dmax= 5.7e-03 nm, Epot= -1.11136e+05 Fmax= 4.56200e+03, atom= 149
# Step=  335, Dmax= 6.8e-03 nm, Epot= -1.11147e+05 Fmax= 6.03381e+03, atom= 149
# Step=  336, Dmax= 8.1e-03 nm, Epot= -1.11160e+05 Fmax= 6.44539e+03, atom= 149
# Step=  337, Dmax= 9.8e-03 nm, Epot= -1.11161e+05 Fmax= 8.76052e+03, atom= 149
# Step=  338, Dmax= 1.2e-02 nm, Epot= -1.11172e+05 Fmax= 9.24551e+03, atom= 149
# Step=  340, Dmax= 7.0e-03 nm, Epot= -1.11222e+05 Fmax= 1.67299e+03, atom= 149
# Step=  341, Dmax= 8.4e-03 nm, Epot= -1.11223e+05 Fmax= 1.10112e+04, atom= 149
# Step=  342, Dmax= 1.0e-02 nm, Epot= -1.11283e+05 Fmax= 4.70925e+03, atom= 149
# Step=  344, Dmax= 6.1e-03 nm, Epot= -1.11298e+05 Fmax= 4.58863e+03, atom= 149
# Step=  345, Dmax= 7.3e-03 nm, Epot= -1.11305e+05 Fmax= 6.79299e+03, atom= 149
# Step=  346, Dmax= 8.8e-03 nm, Epot= -1.11320e+05 Fmax= 6.63535e+03, atom= 149
# Step=  348, Dmax= 5.3e-03 nm, Epot= -1.11350e+05 Fmax= 1.53215e+03, atom= 149
# Step=  349, Dmax= 6.3e-03 nm, Epot= -1.11367e+05 Fmax= 7.91963e+03, atom= 149
# Step=  350, Dmax= 7.6e-03 nm, Epot= -1.11402e+05 Fmax= 3.83161e+03, atom= 149
# Step=  352, Dmax= 4.5e-03 nm, Epot= -1.11417e+05 Fmax= 3.09739e+03, atom= 149
# Step=  353, Dmax= 5.4e-03 nm, Epot= -1.11428e+05 Fmax= 5.43643e+03, atom= 149
# Step=  354, Dmax= 6.5e-03 nm, Epot= -1.11445e+05 Fmax= 4.57609e+03, atom= 149
# Step=  355, Dmax= 7.8e-03 nm, Epot= -1.11446e+05 Fmax= 7.65421e+03, atom= 149
# Step=  356, Dmax= 9.4e-03 nm, Epot= -1.11465e+05 Fmax= 6.79421e+03, atom= 149
# Step=  358, Dmax= 5.6e-03 nm, Epot= -1.11496e+05 Fmax= 1.98049e+03, atom= 149
# Step=  359, Dmax= 6.8e-03 nm, Epot= -1.11501e+05 Fmax= 8.25869e+03, atom= 149
# Step=  360, Dmax= 8.1e-03 nm, Epot= -1.11537e+05 Fmax= 4.36524e+03, atom= 149
# Step=  362, Dmax= 4.9e-03 nm, Epot= -1.11553e+05 Fmax= 3.09617e+03, atom= 149
# Step=  363, Dmax= 5.9e-03 nm, Epot= -1.11561e+05 Fmax= 6.07078e+03, atom= 149
# Step=  364, Dmax= 7.0e-03 nm, Epot= -1.11580e+05 Fmax= 4.70370e+03, atom= 149
# Step=  366, Dmax= 4.2e-03 nm, Epot= -1.11599e+05 Fmax= 1.86444e+03, atom= 149
# Step=  367, Dmax= 5.1e-03 nm, Epot= -1.11613e+05 Fmax= 5.77391e+03, atom= 149
# Step=  368, Dmax= 6.1e-03 nm, Epot= -1.11635e+05 Fmax= 3.66922e+03, atom= 149
# Step=  370, Dmax= 3.6e-03 nm, Epot= -1.11650e+05 Fmax= 1.89304e+03, atom= 149
# Step=  371, Dmax= 4.4e-03 nm, Epot= -1.11664e+05 Fmax= 5.00510e+03, atom= 149
# Step=  372, Dmax= 5.2e-03 nm, Epot= -1.11683e+05 Fmax= 3.02987e+03, atom= 149
# Step=  373, Dmax= 6.3e-03 nm, Epot= -1.11687e+05 Fmax= 6.82253e+03, atom= 149
# Step=  374, Dmax= 7.6e-03 nm, Epot= -1.11709e+05 Fmax= 4.77141e+03, atom= 149
# Step=  376, Dmax= 4.5e-03 nm, Epot= -1.11728e+05 Fmax= 2.28527e+03, atom= 149
# Step=  377, Dmax= 5.4e-03 nm, Epot= -1.11738e+05 Fmax= 5.96622e+03, atom= 149
# Step=  378, Dmax= 6.5e-03 nm, Epot= -1.11758e+05 Fmax= 4.17837e+03, atom= 149
# Step=  380, Dmax= 3.9e-03 nm, Epot= -1.11775e+05 Fmax= 1.81126e+03, atom= 149
# Step=  381, Dmax= 4.7e-03 nm, Epot= -1.11788e+05 Fmax= 5.60362e+03, atom= 149
# Step=  382, Dmax= 5.6e-03 nm, Epot= -1.11809e+05 Fmax= 3.04340e+03, atom= 149
# Step=  384, Dmax= 3.4e-03 nm, Epot= -1.11822e+05 Fmax= 2.24791e+03, atom= 149
# Step=  385, Dmax= 4.1e-03 nm, Epot= -1.11836e+05 Fmax= 3.91392e+03, atom= 149
# Step=  386, Dmax= 4.9e-03 nm, Epot= -1.11849e+05 Fmax= 3.68345e+03, atom= 149
# Step=  387, Dmax= 5.8e-03 nm, Epot= -1.11858e+05 Fmax= 5.25006e+03, atom= 149
# Step=  388, Dmax= 7.0e-03 nm, Epot= -1.11870e+05 Fmax= 5.66102e+03, atom= 149
# Step=  389, Dmax= 8.4e-03 nm, Epot= -1.11874e+05 Fmax= 7.24755e+03, atom= 149
# Step=  390, Dmax= 1.0e-02 nm, Epot= -1.11879e+05 Fmax= 8.42688e+03, atom= 149
# Step=  392, Dmax= 6.1e-03 nm, Epot= -1.11921e+05 Fmax= 8.89410e+02, atom= 149
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 1000 in 393 steps
# Potential Energy  = -1.1192074e+05
# Maximum force     =  8.8940979e+02 on atom 149
# Norm of force     =  4.0556616e+01
#
# GROMACS reminds you: "The Microsecond is Within Reach" (P.J. Van Maaren)

# %% [markdown]
# ### Save analysis results or plots to file.

# %%
mdp_content = """; NVT Equilibration (Constant Volume and Temperature)
; This step stabilizes the system at 300K before proceeding to NPT equilibration.

; Algorithm for integration
integrator    = md        ; Molecular dynamics integrator

; Simulation steps
nsteps        = 50000     ; Run simulation for 50,000 steps
dt            = 0.002     ; Time step of 2 fs

; Output control
nstxout       = 1000      ; Save coordinates every 1000 steps
nstvout       = 1000      ; Save velocities every 1000 steps
nstenergy     = 1000      ; Save energy every 1000 steps
nstlog        = 1000      ; Write log every 1000 steps

; Constraints
continuation  = no        ; Start fresh, not continuing from a previous run
constraint_algorithm = lincs  ; Apply LINCS algorithm to constrain bonds
constraints   = all-bonds ; Constrain all bonds
lincs_iter    = 1         ; Number of iterations in LINCS
lincs_order   = 4         ; Maximum order of the expansion in LINCS

; Neighbor searching
cutoff-scheme = Verlet    ; Use Verlet cutoff scheme
ns_type       = grid      ; Grid-based neighbor searching
nstlist       = 10        ; Update neighbor list every 10 steps

; Electrostatics and van der Waals interactions
rcoulomb      = 1.0       ; Coulomb interaction cutoff distance (nm)
rvdw          = 1.0       ; Van der Waals interaction cutoff distance (nm)
coulombtype   = PME       ; Particle-Mesh Ewald (PME) for long-range electrostatics

; Temperature coupling (Thermostat)
tcoupl        = V-rescale ; Velocity rescaling thermostat
tc-grps       = System    ; Apply temperature coupling to the entire system
tau_t         = 0.1       ; Time constant for temperature coupling
ref_t         = 300       ; Reference temperature (K)

; Pressure coupling (disabled for NVT)
pcoupl        = no        ; No pressure coupling in NVT

; Periodic boundary conditions
pbc           = xyz       ; Use periodic boundary conditions in all directions
"""

file_path = "/content/drive/MyDrive/Rayca_eval/MD_simulation/nvt.mdp"

# Save the .mdp file
with open(file_path, "w") as f:
    f.write(mdp_content)

print(f"Saved nvt.mdp to {file_path}")
# Out:
# Saved nvt.mdp to /content/drive/MyDrive/Rayca_eval/MD_simulation/nvt.mdp

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f /content/drive/MyDrive/Rayca_eval/MD_simulation/nvt.mdp -c neutralized_pocket.gro -r neutralized_pocket.gro -p topol.top -o nvt.tpr
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f /content/drive/MyDrive/Rayca_eval/MD_simulation/nvt.mdp -c neutralized_pocket.gro -r neutralized_pocket.gro -p topol.top -o nvt.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to 2046754286
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# turning all bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning all bonds into constraints...
#
# NOTE 1 [file unknown]:
#   You are using constraints on all bonds, whereas the forcefield has been
#   parametrized only with constraints involving hydrogen atoms. We suggest
#   using constraints = h-bonds instead, this will also improve performance.
#
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group System is 13671.00
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.036 nm, buffer size 0.036 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.114 0.114 0.114
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 9 Mb of data
#
# There was 1 note
#
# GROMACS reminds you: "Problems worthy / of attack / prove their worth / by hitting back." (Piet Hein)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !echo 1 | gmx mdrun -v -deffnm nvt
# Out:
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -v -deffnm nvt
#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file nvt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Changing nstlist from 10 to 40, rlist from 1 to 1.097
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Step 0, time 0 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.296228, max 2.297874 (between atoms 123 and 124)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
# Wrote pdb files with previous and current coordinates
#
# Step 0, time 0 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.127468, max 1.326567 (between atoms 123 and 125)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#       5     20   41.0    0.1708   0.1613      0.1522
#      20     22   31.1    0.1691   0.1452      0.1335
#      36     37   34.5    0.1541   0.1312      0.1229
#      36     38   40.6    0.2077   0.1437      0.1335
#      38     39   43.2    0.1587   0.1087      0.1010
#      40     41   44.7    0.1332   0.1195      0.1090
#      40     42   36.1    0.1747   0.1598      0.1529
#      40     58   30.2    0.1758   0.1563      0.1522
#      78     88   30.5    0.1774   0.1627      0.1522
#      92     93   30.7    0.1237   0.1129      0.1090
#     112    123   35.2    0.3662   0.1764      0.1522
#     123    124   59.4    0.4053   0.1846      0.1229
#     123    125   86.9    0.1652   0.3106      0.1335
#     125    126   61.6    0.1753   0.1423      0.1010
#     125    127   46.6    0.2970   0.1944      0.1449
#     127    128   61.4    0.1389   0.1356      0.1090
#     127    129   44.3    0.1776   0.1675      0.1529
#     127    135   45.6    0.1799   0.1670      0.1522
#
# Back Off! I just backed up step0b.pdb to ./#step0b.pdb.1#
#
# Back Off! I just backed up step0c.pdb to ./#step0c.pdb.1#
# Wrote pdb files with previous and current coordinates
# starting mdrun 'Protein in water'
# 50000 steps,    100.0 ps.
#
# Step 0, time 0 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 3.732585, max 34.501911 (between atoms 10 and 11)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#       5      6  110.9    0.1817   0.0773      0.1090
#       5      7   93.9    0.2259   0.1406      0.1529
#       5     20   88.7    0.1708   0.7320      0.1522
#       7      9   63.6    0.1195   0.1613      0.1090
#       7     10   43.6    0.1628   0.1892      0.1529
#      10     11  149.2    0.1106   3.8697      0.1090
#      20     21   87.8    0.1674   0.6036      0.1229
#      20     22   90.6    0.1691   0.5748      0.1335
#      22     23   87.1    0.1227   0.0599      0.1010
#      22     24   88.3    0.1839   0.7035      0.1449
#      24     25   91.1    0.1136   1.4226      0.1090
#      24     26   88.2    0.1748   0.7995      0.1529
#      24     36   88.8    0.1435   1.0085      0.1522
#      26     27   44.1    0.1188   0.1474      0.1090
#      26     32   33.3    0.1616   0.1860      0.1529
#      28     29   30.7    0.1100   0.1302      0.1090
#      28     30   39.5    0.1100   0.1402      0.1090
#      28     31   37.9    0.1100   0.1380      0.1090
#      36     37   90.5    0.1541   0.5365      0.1229
#      36     38   87.6    0.2077   1.3181      0.1335
#      38     39   90.4    0.1587   1.6615      0.1010
#      38     40   89.2    0.2694   2.1333      0.1449
#      40     41   86.7    0.1332   0.6474      0.1090
#      40     42   89.5    0.1747   0.8367      0.1529
#      40     58   93.1    0.1758   1.2061      0.1522
#      42     43   47.7    0.1113   0.1453      0.1090
#      42     45   38.1    0.1548   0.1844      0.1529
#      58     59   91.5    0.1252   0.8032      0.1229
#      58     60   94.5    0.1363   0.4023      0.1335
#      60     61   97.7    0.1020   0.1267      0.1010
#      60     62  117.3    0.1465   0.0502      0.1449
#      62     63   30.6    0.1097   0.1141      0.1090
#      76     78   36.5    0.2141   0.1654      0.1449
#      78     79   92.6    0.1674   0.6882      0.1090
#      78     80   37.2    0.2217   0.1730      0.1529
#      78     88   48.6    0.1774   0.1625      0.1522
#      88     89   30.3    0.1351   0.1156      0.1229
#      92     93   32.8    0.1237   0.1131      0.1090
#     104    105   90.1    0.1081   0.2742      0.1080
#     112    123   45.0    0.3662   0.1676      0.1522
#     117    118   90.0    0.1093   0.1957      0.1090
#     120    121   90.1    0.1102   0.4632      0.1090
#     123    124   65.0    0.4053   0.1870      0.1229
#     123    125   84.3    0.1652   0.3454      0.1335
#     125    126   64.1    0.1753   0.1450      0.1010
#     125    127   43.1    0.2970   0.1865      0.1449
#     127    128   62.7    0.1389   0.1290      0.1090
#     127    129   39.5    0.1776   0.1643      0.1529
#     127    135   41.1    0.1799   0.1629      0.1522
#     129    131   34.5    0.1129   0.1079      0.1090
#
# step 0: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
#
# Back Off! I just backed up step0b.pdb to ./#step0b.pdb.2#
#
# Back Off! I just backed up step0c.pdb to ./#step0c.pdb.2#
# Wrote pdb files with previous and current coordinates
# step 0/bin/bash: line 1: 10363 Done                    echo 1
#      10364 Segmentation fault      (core dumped) | gmx mdrun -v -deffnm nvt

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx editconf -f step0c.pdb -o /content/drive/MyDrive/Rayca_eval/MD_simulation/water_only.pdb
# Out:
#              :-) GROMACS - gmx editconf, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx editconf -f step0c.pdb -o /content/drive/MyDrive/Rayca_eval/MD_simulation/water_only.pdb
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 6838 atoms
# Volume: 69.5634 nm^3, corresponds to roughly 31300 electrons
# No velocities found
#
# GROMACS reminds you: "During my undergraduate work I concluded that electrostatics is unlikely to be important [for enzymes]" (Arieh Warshel, Nobel lecture 2013)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !echo "Protein" | gmx select -f step0c.pdb -s nvt.tpr -on /content/drive/MyDrive/Rayca_eval/MD_simulation/bad_waters.ndx -select 'same residue as (name OW and within 0.2 of group "Protein")'
# Out:
#               :-) GROMACS - gmx select, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx select, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx select -f step0c.pdb -s nvt.tpr -on /content/drive/MyDrive/Rayca_eval/MD_simulation/bad_waters.ndx -select 'same residue as (name OW and within 0.2 of group "Protein")'
#
# Reading file nvt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file nvt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading frame       0 time    0.000    '', 6838 atoms
# Last frame          0 time    0.000
# Analyzed 1 frames, last time 0.000
#
# GROMACS reminds you: "Put Me Inside SSC, Let's Test Superstring Theory, Oh Yoi Yoi Accelerate the Protons" (Gogol Bordello)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !echo "bad_waters" | gmx trjconv -s nvt.tpr -f step0c.pdb -n /content/drive/MyDrive/Rayca_eval/MD_simulation/bad_waters.ndx -o /content/drive/MyDrive/Rayca_eval/MD_simulation/bad_waters.pdb
# Out:
#              :-) GROMACS - gmx trjconv, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx trjconv -s nvt.tpr -f step0c.pdb -n /content/drive/MyDrive/Rayca_eval/MD_simulation/bad_waters.ndx -o /content/drive/MyDrive/Rayca_eval/MD_simulation/bad_waters.pdb
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
# Reading file nvt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file nvt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Select group for output
# Group     0 (same_residue_as_(name_OW_and_within_0.2_of_group_"Protein")_f0_t0.000) has    45 elements
# There is one group in the index
# Reading frame       0 time    0.000
# Precision of step0c.pdb is 0.0001 (nm)
#  '', 6838 atoms
# Last frame          0 time    0.000
#
#
# GROMACS reminds you: "What They Need's a Damn Good Whacking" (The Beatles)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx editconf -f step0c.pdb -o cleaned_pocket.pdb -c -d 1.0
# Out:
#              :-) GROMACS - gmx editconf, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx editconf -f step0c.pdb -o cleaned_pocket.pdb -c -d 1.0
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 6838 atoms
# Volume: 69.5634 nm^3, corresponds to roughly 31300 electrons
# No velocities found
#     system size :  7.049  9.799  4.311 (nm)
#     center      :   -nan   -nan   -nan (nm)
#     box vectors :  4.113  4.113  4.113 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :  69.56               (nm^3)
#     shift       :   -nan   -nan   -nan (nm)
# new center      :   -nan   -nan   -nan (nm)
# new box vectors :  9.049 11.799  6.311 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 673.82               (nm^3)
#
# WARNING: No boxtype specified - distance condition applied in each dimension.
# If the molecule rotates the actual distance will be smaller. You might want
# to use a cubic box instead, or why not try a dodecahedron today?
#
# GROMACS reminds you: "Safety lights are for dudes" (Ghostbusters 2016)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx solvate -cp cleaned_pocket.pdb -cs spc216.gro -o solvated.gro -p topol.top
# Out:
#              :-) GROMACS - gmx solvate, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx solvate, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx solvate -cp cleaned_pocket.pdb -cs spc216.gro -o solvated.gro -p topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 5x7x4 boxes
# Solvent box contains 74550 atoms in 24850 residues
# Removed 8820 solvent atoms due to solvent-solvent overlap

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f ions.mdp -c solvated.gro -p topol.top -o ions.tpr
# !echo 13 | gmx genion -s ions.tpr -o neutralized_pocket.gro -p topol.top -pname NA -nname CL -neutral
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f ions.mdp -c solvated.gro -p topol.top -o ions.tpr
#
#
# -------------------------------------------------------
# Program:     gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 275)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -c
#     File 'solvated.gro' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#               :-) GROMACS - gmx genion, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx genion, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx genion -s ions.tpr -o neutralized_pocket.gro -p topol.top -pname NA -nname CL -neutral
#
# Reading file ions.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file ions.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# No ions to add, will just copy input configuration.
#
# Back Off! I just backed up neutralized_pocket.gro to ./#neutralized_pocket.gro.1#
#
# GROMACS reminds you: "If it's all right with Dirac, it's all right with me." (Enrico Fermi, on being told that there was experimental evidence He-3 nuclei obey Fermi-Dirac statistics.)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f em.mdp -c neutralized_pocket.gro -p topol.top -o em.tpr
# !gmx mdrun -v -deffnm em
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f em.mdp -c neutralized_pocket.gro -p topol.top -o em.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file em.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -1901080835
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group rest is 13824.00
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.114 0.114 0.114
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 1 Mb of data
#
# There was 1 note
#
# Back Off! I just backed up em.tpr to ./#em.tpr.1#
#
# GROMACS reminds you: "Keep Your Shoes and Socks On, People" (F. Zappa)
#
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -v -deffnm em
#
#
# Back Off! I just backed up em.log to ./#em.log.1#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file em.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Back Off! I just backed up em.trr to ./#em.trr.1#
#
# Back Off! I just backed up em.edr to ./#em.edr.1#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =        50000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  1.51249e+05 Fmax= 2.80235e+05, atom= 123
# Step=    1, Dmax= 1.0e-02 nm, Epot=  1.33341e+05 Fmax= 2.70525e+05, atom= 123
# Step=    2, Dmax= 1.2e-02 nm, Epot=  1.15641e+05 Fmax= 2.58758e+05, atom= 123
# Step=    3, Dmax= 1.4e-02 nm, Epot=  9.73602e+04 Fmax= 2.44205e+05, atom= 123
# Step=    4, Dmax= 1.7e-02 nm, Epot=  7.82827e+04 Fmax= 2.25749e+05, atom= 123
# Step=    5, Dmax= 2.1e-02 nm, Epot=  5.84859e+04 Fmax= 2.01723e+05, atom= 123
# Step=    6, Dmax= 2.5e-02 nm, Epot=  3.83130e+04 Fmax= 1.68504e+05, atom= 123
# Step=    7, Dmax= 3.0e-02 nm, Epot=  1.83793e+04 Fmax= 1.24699e+05, atom= 125
# Step=    8, Dmax= 3.6e-02 nm, Epot= -4.77837e+01 Fmax= 9.71601e+04, atom= 118
# Step=    9, Dmax= 4.3e-02 nm, Epot= -1.37130e+04 Fmax= 1.22254e+05, atom= 118
# Step=   10, Dmax= 5.2e-02 nm, Epot= -2.21221e+04 Fmax= 4.65922e+05, atom= 118
# Step=   11, Dmax= 6.2e-02 nm, Epot= -2.57348e+04 Fmax= 1.28029e+05, atom= 123
# Step=   12, Dmax= 7.4e-02 nm, Epot= -3.85895e+04 Fmax= 9.08264e+04, atom= 123
# Step=   13, Dmax= 8.9e-02 nm, Epot= -4.58646e+04 Fmax= 1.86983e+05, atom= 123
#
# step 14: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
#
# Back Off! I just backed up step14b.pdb to ./#step14b.pdb.1#
#
# Back Off! I just backed up step14c.pdb to ./#step14c.pdb.1#
# Wrote pdb files with previous and current coordinates
# Step=   15, Dmax= 5.3e-02 nm, Epot= -5.30074e+04 Fmax= 4.10912e+04, atom= 123
# Step=   16, Dmax= 6.4e-02 nm, Epot= -6.26564e+04 Fmax= 1.04630e+05, atom= 123
# Step=   17, Dmax= 7.7e-02 nm, Epot= -6.51139e+04 Fmax= 6.37031e+04, atom= 123
# Step=   18, Dmax= 9.2e-02 nm, Epot= -6.99420e+04 Fmax= 5.17883e+04, atom= 123
# Step=   20, Dmax= 5.5e-02 nm, Epot= -7.29888e+04 Fmax= 4.67681e+04, atom= 123
# Step=   21, Dmax= 6.7e-02 nm, Epot= -7.53197e+04 Fmax= 4.44560e+04, atom= 123
# Step=   23, Dmax= 4.0e-02 nm, Epot= -7.79004e+04 Fmax= 2.80959e+04, atom= 123
# Step=   24, Dmax= 4.8e-02 nm, Epot= -7.94528e+04 Fmax= 4.51941e+04, atom= 123
# Step=   25, Dmax= 5.8e-02 nm, Epot= -8.03683e+04 Fmax= 5.61424e+04, atom= 123
# Step=   26, Dmax= 6.9e-02 nm, Epot= -8.18078e+04 Fmax= 5.01270e+04, atom= 123
# Step=   28, Dmax= 4.1e-02 nm, Epot= -8.35989e+04 Fmax= 2.29298e+04, atom= 123
# Step=   29, Dmax= 5.0e-02 nm, Epot= -8.42896e+04 Fmax= 5.72307e+04, atom= 123
# Step=   30, Dmax= 6.0e-02 nm, Epot= -8.53136e+04 Fmax= 4.21756e+04, atom= 123
# Step=   31, Dmax= 7.2e-02 nm, Epot= -8.53348e+04 Fmax= 6.98377e+04, atom= 123
# Step=   32, Dmax= 8.6e-02 nm, Epot= -8.57565e+04 Fmax= 6.29191e+04, atom= 123
# Step=   34, Dmax= 5.2e-02 nm, Epot= -8.82395e+04 Fmax= 1.12252e+04, atom= 123
# Step=   36, Dmax= 3.1e-02 nm, Epot= -8.91119e+04 Fmax= 3.04470e+04, atom= 123
# Step=   37, Dmax= 3.7e-02 nm, Epot= -8.99596e+04 Fmax= 1.92444e+04, atom= 123
# Step=   39, Dmax= 2.2e-02 nm, Epot= -9.05819e+04 Fmax= 1.57502e+04, atom= 123
# Step=   40, Dmax= 2.7e-02 nm, Epot= -9.10741e+04 Fmax= 2.05652e+04, atom= 123
# Step=   41, Dmax= 3.2e-02 nm, Epot= -9.14514e+04 Fmax= 2.77695e+04, atom= 123
# Step=   42, Dmax= 3.8e-02 nm, Epot= -9.19312e+04 Fmax= 2.62194e+04, atom= 123
# Step=   44, Dmax= 2.3e-02 nm, Epot= -9.26027e+04 Fmax= 8.41545e+03, atom= 123
# Step=   45, Dmax= 2.8e-02 nm, Epot= -9.31450e+04 Fmax= 2.84022e+04, atom= 123
# Step=   46, Dmax= 3.3e-02 nm, Epot= -9.37020e+04 Fmax= 1.99016e+04, atom= 123
# Step=   48, Dmax= 2.0e-02 nm, Epot= -9.41464e+04 Fmax= 7.22431e+03, atom= 123
# Step=   49, Dmax= 2.4e-02 nm, Epot= -9.45044e+04 Fmax= 2.84602e+04, atom= 123
# Step=   50, Dmax= 2.9e-02 nm, Epot= -9.51435e+04 Fmax= 1.09771e+04, atom= 123
# Step=   52, Dmax= 1.7e-02 nm, Epot= -9.54509e+04 Fmax= 1.40216e+04, atom= 123
# Step=   53, Dmax= 2.1e-02 nm, Epot= -9.57468e+04 Fmax= 1.39377e+04, atom= 123
# Step=   54, Dmax= 2.5e-02 nm, Epot= -9.59456e+04 Fmax= 2.12526e+04, atom= 123
# Step=   55, Dmax= 3.0e-02 nm, Epot= -9.62466e+04 Fmax= 1.92765e+04, atom= 123
# Step=   57, Dmax= 1.8e-02 nm, Epot= -9.66557e+04 Fmax= 6.02048e+03, atom= 123
# Step=   58, Dmax= 2.1e-02 nm, Epot= -9.69555e+04 Fmax= 2.17975e+04, atom= 123
# Step=   59, Dmax= 2.6e-02 nm, Epot= -9.73556e+04 Fmax= 1.39620e+04, atom= 123
# Step=   61, Dmax= 1.5e-02 nm, Epot= -9.76430e+04 Fmax= 6.61092e+03, atom= 123
# Step=   62, Dmax= 1.9e-02 nm, Epot= -9.76993e+04 Fmax= 1.96766e+04, atom= 123
# Step=   63, Dmax= 2.2e-02 nm, Epot= -9.81326e+04 Fmax= 1.25792e+04, atom= 132
# Step=   65, Dmax= 1.3e-02 nm, Epot= -9.84030e+04 Fmax= 7.22582e+03, atom= 132
# Step=   66, Dmax= 1.6e-02 nm, Epot= -9.85186e+04 Fmax= 1.76199e+04, atom= 132
# Step=   67, Dmax= 1.9e-02 nm, Epot= -9.88181e+04 Fmax= 1.10431e+04, atom= 132
# Step=   69, Dmax= 1.2e-02 nm, Epot= -9.90195e+04 Fmax= 6.65001e+03, atom= 132
# Step=   70, Dmax= 1.4e-02 nm, Epot= -9.91856e+04 Fmax= 1.36727e+04, atom= 132
# Step=   71, Dmax= 1.7e-02 nm, Epot= -9.93770e+04 Fmax= 1.16795e+04, atom= 132
# Step=   72, Dmax= 2.0e-02 nm, Epot= -9.94486e+04 Fmax= 1.79495e+04, atom= 132
# Step=   73, Dmax= 2.4e-02 nm, Epot= -9.95982e+04 Fmax= 1.83175e+04, atom= 132
# Step=   75, Dmax= 1.4e-02 nm, Epot= -9.99139e+04 Fmax= 3.06542e+03, atom= 132
# Step=   76, Dmax= 1.7e-02 nm, Epot= -1.00092e+05 Fmax= 2.42683e+04, atom= 132
# Step=   77, Dmax= 2.1e-02 nm, Epot= -1.00594e+05 Fmax= 6.80014e+03, atom= 132
# Step=   79, Dmax= 1.2e-02 nm, Epot= -1.00690e+05 Fmax= 1.22179e+04, atom= 132
# Step=   80, Dmax= 1.5e-02 nm, Epot= -1.00844e+05 Fmax= 1.00182e+04, atom= 132
# Step=   82, Dmax= 8.9e-03 nm, Epot= -1.01012e+05 Fmax= 3.58510e+03, atom= 132
# Step=   83, Dmax= 1.1e-02 nm, Epot= -1.01152e+05 Fmax= 1.26119e+04, atom= 149
# Step=   84, Dmax= 1.3e-02 nm, Epot= -1.01351e+05 Fmax= 7.29618e+03, atom= 149
# Step=   86, Dmax= 7.7e-03 nm, Epot= -1.01475e+05 Fmax= 4.59792e+03, atom= 149
# Step=   87, Dmax= 9.2e-03 nm, Epot= -1.01592e+05 Fmax= 9.77597e+03, atom= 149
# Step=   88, Dmax= 1.1e-02 nm, Epot= -1.01724e+05 Fmax= 7.35951e+03, atom= 149
# Step=   89, Dmax= 1.3e-02 nm, Epot= -1.01784e+05 Fmax= 1.33071e+04, atom= 149
# Step=   90, Dmax= 1.6e-02 nm, Epot= -1.01922e+05 Fmax= 1.13547e+04, atom= 149
# Step=   92, Dmax= 9.6e-03 nm, Epot= -1.02078e+05 Fmax= 3.50655e+03, atom= 149
# Step=   93, Dmax= 1.1e-02 nm, Epot= -1.02210e+05 Fmax= 1.41436e+04, atom= 149
# Step=   94, Dmax= 1.4e-02 nm, Epot= -1.02387e+05 Fmax= 7.26381e+03, atom= 149
# Step=   96, Dmax= 8.3e-03 nm, Epot= -1.02488e+05 Fmax= 5.49232e+03, atom= 149
# Step=   97, Dmax= 9.9e-03 nm, Epot= -1.02580e+05 Fmax= 9.97789e+03, atom= 149
# Step=   98, Dmax= 1.2e-02 nm, Epot= -1.02685e+05 Fmax= 8.40942e+03, atom= 149
# Step=   99, Dmax= 1.4e-02 nm, Epot= -1.02735e+05 Fmax= 1.38188e+04, atom= 149
# Step=  100, Dmax= 1.7e-02 nm, Epot= -1.02842e+05 Fmax= 1.26522e+04, atom= 149
# Step=  102, Dmax= 1.0e-02 nm, Epot= -1.02988e+05 Fmax= 3.32503e+03, atom= 149
# Step=  103, Dmax= 1.2e-02 nm, Epot= -1.03108e+05 Fmax= 1.55642e+04, atom= 149
# Step=  104, Dmax= 1.5e-02 nm, Epot= -1.03279e+05 Fmax= 7.45520e+03, atom= 149
# Step=  106, Dmax= 8.9e-03 nm, Epot= -1.03365e+05 Fmax= 6.23075e+03, atom= 149
# Step=  107, Dmax= 1.1e-02 nm, Epot= -1.03438e+05 Fmax= 1.04130e+04, atom= 149
# Step=  108, Dmax= 1.3e-02 nm, Epot= -1.03526e+05 Fmax= 9.32345e+03, atom= 149
# Step=  109, Dmax= 1.5e-02 nm, Epot= -1.03561e+05 Fmax= 1.45783e+04, atom= 149
# Step=  110, Dmax= 1.8e-02 nm, Epot= -1.03649e+05 Fmax= 1.38404e+04, atom= 149
# Step=  112, Dmax= 1.1e-02 nm, Epot= -1.03795e+05 Fmax= 3.33335e+03, atom= 149
# Step=  113, Dmax= 1.3e-02 nm, Epot= -1.03885e+05 Fmax= 1.69007e+04, atom= 149
# Step=  114, Dmax= 1.6e-02 nm, Epot= -1.04058e+05 Fmax= 7.84697e+03, atom= 149
# Step=  116, Dmax= 9.6e-03 nm, Epot= -1.04134e+05 Fmax= 6.84360e+03, atom= 149
# Step=  117, Dmax= 1.1e-02 nm, Epot= -1.04190e+05 Fmax= 1.10554e+04, atom= 149
# Step=  118, Dmax= 1.4e-02 nm, Epot= -1.04267e+05 Fmax= 1.01369e+04, atom= 149
# Step=  119, Dmax= 1.7e-02 nm, Epot= -1.04285e+05 Fmax= 1.55570e+04, atom= 149
# Step=  120, Dmax= 2.0e-02 nm, Epot= -1.04361e+05 Fmax= 1.49596e+04, atom= 149
# Step=  122, Dmax= 1.2e-02 nm, Epot= -1.04513e+05 Fmax= 3.49575e+03, atom= 149
# Step=  123, Dmax= 1.4e-02 nm, Epot= -1.04562e+05 Fmax= 1.82097e+04, atom= 149
# Step=  124, Dmax= 1.7e-02 nm, Epot= -1.04743e+05 Fmax= 8.38948e+03, atom= 149
# Step=  126, Dmax= 1.0e-02 nm, Epot= -1.04812e+05 Fmax= 7.38686e+03, atom= 149
# Step=  127, Dmax= 1.2e-02 nm, Epot= -1.04852e+05 Fmax= 1.18547e+04, atom= 149
# Step=  128, Dmax= 1.5e-02 nm, Epot= -1.04922e+05 Fmax= 1.09078e+04, atom= 149
# Step=  130, Dmax= 8.9e-03 nm, Epot= -1.05018e+05 Fmax= 2.90771e+03, atom= 149
# Step=  131, Dmax= 1.1e-02 nm, Epot= -1.05107e+05 Fmax= 1.32119e+04, atom= 149
# Step=  132, Dmax= 1.3e-02 nm, Epot= -1.05218e+05 Fmax= 6.68007e+03, atom= 149
# Step=  134, Dmax= 7.7e-03 nm, Epot= -1.05280e+05 Fmax= 5.07304e+03, atom= 149
# Step=  135, Dmax= 9.2e-03 nm, Epot= -1.05332e+05 Fmax= 9.36532e+03, atom= 149
# Step=  136, Dmax= 1.1e-02 nm, Epot= -1.05398e+05 Fmax= 7.60664e+03, atom= 149
# Step=  137, Dmax= 1.3e-02 nm, Epot= -1.05420e+05 Fmax= 1.30886e+04, atom= 149
# Step=  138, Dmax= 1.6e-02 nm, Epot= -1.05492e+05 Fmax= 1.13788e+04, atom= 149
# Step=  140, Dmax= 9.6e-03 nm, Epot= -1.05588e+05 Fmax= 3.47013e+03, atom= 149
# Step=  141, Dmax= 1.1e-02 nm, Epot= -1.05638e+05 Fmax= 1.38944e+04, atom= 149
# Step=  142, Dmax= 1.4e-02 nm, Epot= -1.05748e+05 Fmax= 7.48088e+03, atom= 149
# Step=  144, Dmax= 8.3e-03 nm, Epot= -1.05808e+05 Fmax= 5.15489e+03, atom= 149
# Step=  145, Dmax= 9.9e-03 nm, Epot= -1.05847e+05 Fmax= 1.03696e+04, atom= 149
# Step=  146, Dmax= 1.2e-02 nm, Epot= -1.05915e+05 Fmax= 7.87456e+03, atom= 149
# Step=  147, Dmax= 1.4e-02 nm, Epot= -1.05917e+05 Fmax= 1.43681e+04, atom= 149
# Step=  148, Dmax= 1.7e-02 nm, Epot= -1.05994e+05 Fmax= 1.19272e+04, atom= 149
# Step=  150, Dmax= 1.0e-02 nm, Epot= -1.06091e+05 Fmax= 4.02721e+03, atom= 149
# Step=  151, Dmax= 1.2e-02 nm, Epot= -1.06110e+05 Fmax= 1.46700e+04, atom= 149
# Step=  152, Dmax= 1.5e-02 nm, Epot= -1.06222e+05 Fmax= 8.29529e+03, atom= 149
# Step=  154, Dmax= 8.9e-03 nm, Epot= -1.06281e+05 Fmax= 5.28975e+03, atom= 149
# Step=  155, Dmax= 1.1e-02 nm, Epot= -1.06307e+05 Fmax= 1.13959e+04, atom= 149
# Step=  156, Dmax= 1.3e-02 nm, Epot= -1.06378e+05 Fmax= 8.21670e+03, atom= 149
# Step=  158, Dmax= 7.7e-03 nm, Epot= -1.06439e+05 Fmax= 3.73591e+03, atom= 149
# Step=  159, Dmax= 9.2e-03 nm, Epot= -1.06483e+05 Fmax= 1.01983e+04, atom= 149
# Step=  160, Dmax= 1.1e-02 nm, Epot= -1.06550e+05 Fmax= 6.99061e+03, atom= 149
# Step=  161, Dmax= 1.3e-02 nm, Epot= -1.06553e+05 Fmax= 1.32538e+04, atom= 149
# Step=  162, Dmax= 1.6e-02 nm, Epot= -1.06618e+05 Fmax= 1.14365e+04, atom= 149
# Step=  164, Dmax= 9.5e-03 nm, Epot= -1.06706e+05 Fmax= 3.19825e+03, atom= 149
# Step=  165, Dmax= 1.1e-02 nm, Epot= -1.06725e+05 Fmax= 1.49103e+04, atom= 149
# Step=  166, Dmax= 1.4e-02 nm, Epot= -1.06845e+05 Fmax= 6.21259e+03, atom= 149
# Step=  168, Dmax= 8.2e-03 nm, Epot= -1.06887e+05 Fmax= 6.67644e+03, atom= 149
# Step=  169, Dmax= 9.9e-03 nm, Epot= -1.06922e+05 Fmax= 8.43127e+03, atom= 149
# Step=  170, Dmax= 1.2e-02 nm, Epot= -1.06954e+05 Fmax= 1.00706e+04, atom= 149
# Step=  171, Dmax= 1.4e-02 nm, Epot= -1.06980e+05 Fmax= 1.17540e+04, atom= 149
# Step=  172, Dmax= 1.7e-02 nm, Epot= -1.06988e+05 Fmax= 1.47966e+04, atom= 149
# Step=  173, Dmax= 2.1e-02 nm, Epot= -1.07000e+05 Fmax= 1.66572e+04, atom= 149
# Step=  175, Dmax= 1.2e-02 nm, Epot= -1.07160e+05 Fmax= 2.41289e+03, atom= 149
# Step=  176, Dmax= 1.5e-02 nm, Epot= -1.07161e+05 Fmax= 1.96656e+04, atom= 149
# Step=  177, Dmax= 1.8e-02 nm, Epot= -1.07350e+05 Fmax= 7.84922e+03, atom= 149
# Step=  179, Dmax= 1.1e-02 nm, Epot= -1.07385e+05 Fmax= 8.40855e+03, atom= 149
# Step=  180, Dmax= 1.3e-02 nm, Epot= -1.07401e+05 Fmax= 1.14804e+04, atom= 149
# Step=  181, Dmax= 1.5e-02 nm, Epot= -1.07432e+05 Fmax= 1.19890e+04, atom= 149
# Step=  183, Dmax= 9.2e-03 nm, Epot= -1.07524e+05 Fmax= 2.28638e+03, atom= 149
# Step=  184, Dmax= 1.1e-02 nm, Epot= -1.07565e+05 Fmax= 1.41642e+04, atom= 149
# Step=  185, Dmax= 1.3e-02 nm, Epot= -1.07672e+05 Fmax= 6.39242e+03, atom= 149
# Step=  187, Dmax= 7.9e-03 nm, Epot= -1.07709e+05 Fmax= 5.71852e+03, atom= 149
# Step=  188, Dmax= 9.5e-03 nm, Epot= -1.07731e+05 Fmax= 9.19627e+03, atom= 149
# Step=  189, Dmax= 1.1e-02 nm, Epot= -1.07771e+05 Fmax= 8.30661e+03, atom= 149
# Step=  191, Dmax= 6.9e-03 nm, Epot= -1.07826e+05 Fmax= 2.38467e+03, atom= 149
# Step=  192, Dmax= 8.2e-03 nm, Epot= -1.07873e+05 Fmax= 9.91821e+03, atom= 149
# Step=  193, Dmax= 9.9e-03 nm, Epot= -1.07934e+05 Fmax= 5.45977e+03, atom= 149
# Step=  195, Dmax= 5.9e-03 nm, Epot= -1.07970e+05 Fmax= 3.56543e+03, atom= 149
# Step=  196, Dmax= 7.1e-03 nm, Epot= -1.08001e+05 Fmax= 7.65867e+03, atom= 149
# Step=  197, Dmax= 8.5e-03 nm, Epot= -1.08043e+05 Fmax= 5.39202e+03, atom= 149
# Step=  198, Dmax= 1.0e-02 nm, Epot= -1.08051e+05 Fmax= 1.06513e+04, atom= 149
# Step=  199, Dmax= 1.2e-02 nm, Epot= -1.08102e+05 Fmax= 8.18621e+03, atom= 149
# Step=  201, Dmax= 7.4e-03 nm, Epot= -1.08153e+05 Fmax= 3.30377e+03, atom= 149
# Step=  202, Dmax= 8.8e-03 nm, Epot= -1.08175e+05 Fmax= 1.00470e+04, atom= 149
# Step=  203, Dmax= 1.1e-02 nm, Epot= -1.08232e+05 Fmax= 6.47457e+03, atom= 149
# Step=  205, Dmax= 6.4e-03 nm, Epot= -1.08271e+05 Fmax= 3.24865e+03, atom= 149
# Step=  206, Dmax= 7.6e-03 nm, Epot= -1.08296e+05 Fmax= 8.83489e+03, atom= 149
# Step=  207, Dmax= 9.2e-03 nm, Epot= -1.08345e+05 Fmax= 5.21353e+03, atom= 149
# Step=  209, Dmax= 5.5e-03 nm, Epot= -1.08378e+05 Fmax= 3.41021e+03, atom= 149
# Step=  210, Dmax= 6.6e-03 nm, Epot= -1.08408e+05 Fmax= 6.56811e+03, atom= 149
# Step=  211, Dmax= 7.9e-03 nm, Epot= -1.08442e+05 Fmax= 5.81455e+03, atom= 149
# Step=  212, Dmax= 9.5e-03 nm, Epot= -1.08459e+05 Fmax= 8.68464e+03, atom= 149
# Step=  213, Dmax= 1.1e-02 nm, Epot= -1.08487e+05 Fmax= 9.09017e+03, atom= 149
# Step=  214, Dmax= 1.4e-02 nm, Epot= -1.08491e+05 Fmax= 1.18726e+04, atom= 149
# Step=  215, Dmax= 1.6e-02 nm, Epot= -1.08503e+05 Fmax= 1.36391e+04, atom= 149
# Step=  217, Dmax= 9.9e-03 nm, Epot= -1.08609e+05 Fmax= 1.49996e+03, atom= 149
# Step=  218, Dmax= 1.2e-02 nm, Epot= -1.08635e+05 Fmax= 1.76605e+04, atom= 149
# Step=  219, Dmax= 1.4e-02 nm, Epot= -1.08795e+05 Fmax= 4.22664e+03, atom= 149
# Step=  221, Dmax= 8.5e-03 nm, Epot= -1.08807e+05 Fmax= 9.16240e+03, atom= 149
# Step=  222, Dmax= 1.0e-02 nm, Epot= -1.08850e+05 Fmax= 6.50598e+03, atom= 149
# Step=  224, Dmax= 6.1e-03 nm, Epot= -1.08887e+05 Fmax= 3.07149e+03, atom= 149
# Step=  225, Dmax= 7.4e-03 nm, Epot= -1.08909e+05 Fmax= 8.03500e+03, atom= 149
# Step=  226, Dmax= 8.8e-03 nm, Epot= -1.08949e+05 Fmax= 5.72883e+03, atom= 149
# Step=  228, Dmax= 5.3e-03 nm, Epot= -1.08981e+05 Fmax= 2.35526e+03, atom= 149
# Step=  229, Dmax= 6.4e-03 nm, Epot= -1.09010e+05 Fmax= 7.76581e+03, atom= 149
# Step=  230, Dmax= 7.6e-03 nm, Epot= -1.09052e+05 Fmax= 3.91585e+03, atom= 149
# Step=  231, Dmax= 9.2e-03 nm, Epot= -1.09053e+05 Fmax= 1.04862e+04, atom= 149
# Step=  232, Dmax= 1.1e-02 nm, Epot= -1.09107e+05 Fmax= 6.36914e+03, atom= 149
# Step=  234, Dmax= 6.6e-03 nm, Epot= -1.09141e+05 Fmax= 3.92390e+03, atom= 149
# Step=  235, Dmax= 7.9e-03 nm, Epot= -1.09156e+05 Fmax= 8.07689e+03, atom= 149
# Step=  236, Dmax= 9.5e-03 nm, Epot= -1.09190e+05 Fmax= 6.71174e+03, atom= 149
# Step=  238, Dmax= 5.7e-03 nm, Epot= -1.09226e+05 Fmax= 1.99476e+03, atom= 149
# Step=  239, Dmax= 6.8e-03 nm, Epot= -1.09256e+05 Fmax= 8.93381e+03, atom= 149
# Step=  240, Dmax= 8.2e-03 nm, Epot= -1.09305e+05 Fmax= 3.64095e+03, atom= 149
# Step=  242, Dmax= 4.9e-03 nm, Epot= -1.09330e+05 Fmax= 4.10537e+03, atom= 149
# Step=  243, Dmax= 5.9e-03 nm, Epot= -1.09353e+05 Fmax= 4.86569e+03, atom= 149
# Step=  244, Dmax= 7.1e-03 nm, Epot= -1.09373e+05 Fmax= 6.23629e+03, atom= 149
# Step=  245, Dmax= 8.5e-03 nm, Epot= -1.09395e+05 Fmax= 6.75472e+03, atom= 149
# Step=  246, Dmax= 1.0e-02 nm, Epot= -1.09405e+05 Fmax= 9.16430e+03, atom= 149
# Step=  247, Dmax= 1.2e-02 nm, Epot= -1.09424e+05 Fmax= 9.59883e+03, atom= 149
# Step=  249, Dmax= 7.3e-03 nm, Epot= -1.09483e+05 Fmax= 1.82379e+03, atom= 149
# Step=  250, Dmax= 8.8e-03 nm, Epot= -1.09508e+05 Fmax= 1.12962e+04, atom= 149
# Step=  251, Dmax= 1.1e-02 nm, Epot= -1.09576e+05 Fmax= 5.14589e+03, atom= 149
# Step=  253, Dmax= 6.3e-03 nm, Epot= -1.09600e+05 Fmax= 4.53149e+03, atom= 149
# Step=  254, Dmax= 7.6e-03 nm, Epot= -1.09614e+05 Fmax= 7.40727e+03, atom= 149
# Step=  255, Dmax= 9.1e-03 nm, Epot= -1.09640e+05 Fmax= 6.58293e+03, atom= 149
# Step=  257, Dmax= 5.5e-03 nm, Epot= -1.09675e+05 Fmax= 1.97191e+03, atom= 149
# Step=  258, Dmax= 6.6e-03 nm, Epot= -1.09703e+05 Fmax= 7.85742e+03, atom= 149
# Step=  259, Dmax= 7.9e-03 nm, Epot= -1.09742e+05 Fmax= 4.44389e+03, atom= 149
# Step=  261, Dmax= 4.7e-03 nm, Epot= -1.09766e+05 Fmax= 2.76885e+03, atom= 149
# Step=  262, Dmax= 5.7e-03 nm, Epot= -1.09786e+05 Fmax= 6.22165e+03, atom= 149
# Step=  263, Dmax= 6.8e-03 nm, Epot= -1.09814e+05 Fmax= 4.20983e+03, atom= 149
# Step=  264, Dmax= 8.2e-03 nm, Epot= -1.09819e+05 Fmax= 8.63217e+03, atom= 149
# Step=  265, Dmax= 9.8e-03 nm, Epot= -1.09854e+05 Fmax= 6.42897e+03, atom= 149
# Step=  267, Dmax= 5.9e-03 nm, Epot= -1.09886e+05 Fmax= 2.76501e+03, atom= 149
# Step=  268, Dmax= 7.1e-03 nm, Epot= -1.09900e+05 Fmax= 7.91178e+03, atom= 149
# Step=  269, Dmax= 8.5e-03 nm, Epot= -1.09936e+05 Fmax= 5.30477e+03, atom= 149
# Step=  271, Dmax= 5.1e-03 nm, Epot= -1.09962e+05 Fmax= 2.46921e+03, atom= 149
# Step=  272, Dmax= 6.1e-03 nm, Epot= -1.09979e+05 Fmax= 7.21307e+03, atom= 149
# Step=  273, Dmax= 7.3e-03 nm, Epot= -1.10013e+05 Fmax= 4.01892e+03, atom= 149
# Step=  275, Dmax= 4.4e-03 nm, Epot= -1.10034e+05 Fmax= 2.88382e+03, atom= 149
# Step=  276, Dmax= 5.3e-03 nm, Epot= -1.10054e+05 Fmax= 5.09933e+03, atom= 149
# Step=  277, Dmax= 6.3e-03 nm, Epot= -1.10076e+05 Fmax= 4.80836e+03, atom= 149
# Step=  278, Dmax= 7.6e-03 nm, Epot= -1.10089e+05 Fmax= 6.78704e+03, atom= 149
# Step=  279, Dmax= 9.1e-03 nm, Epot= -1.10106e+05 Fmax= 7.43321e+03, atom= 149
# Step=  280, Dmax= 1.1e-02 nm, Epot= -1.10112e+05 Fmax= 9.33366e+03, atom= 149
# Step=  281, Dmax= 1.3e-02 nm, Epot= -1.10117e+05 Fmax= 1.10804e+04, atom= 149
# Step=  283, Dmax= 7.9e-03 nm, Epot= -1.10188e+05 Fmax= 1.02775e+03, atom= 149
# Step=  284, Dmax= 9.5e-03 nm, Epot= -1.10226e+05 Fmax= 1.44403e+04, atom= 149
# Step=  285, Dmax= 1.1e-02 nm, Epot= -1.10335e+05 Fmax= 3.05780e+03, atom= 149
# Step=  287, Dmax= 6.8e-03 nm, Epot= -1.10344e+05 Fmax= 7.66748e+03, atom= 149
# Step=  288, Dmax= 8.2e-03 nm, Epot= -1.10376e+05 Fmax= 4.86528e+03, atom= 149
# Step=  290, Dmax= 4.9e-03 nm, Epot= -1.10399e+05 Fmax= 2.80016e+03, atom= 149
# Step=  291, Dmax= 5.9e-03 nm, Epot= -1.10414e+05 Fmax= 6.10554e+03, atom= 149
# Step=  292, Dmax= 7.1e-03 nm, Epot= -1.10438e+05 Fmax= 4.90537e+03, atom= 149
# Step=  293, Dmax= 8.5e-03 nm, Epot= -1.10442e+05 Fmax= 8.03046e+03, atom= 149
# Step=  294, Dmax= 1.0e-02 nm, Epot= -1.10463e+05 Fmax= 7.78364e+03, atom= 149
# Step=  296, Dmax= 6.1e-03 nm, Epot= -1.10502e+05 Fmax= 1.57069e+03, atom= 149
# Step=  297, Dmax= 7.3e-03 nm, Epot= -1.10519e+05 Fmax= 1.01485e+04, atom= 149
# Step=  298, Dmax= 8.8e-03 nm, Epot= -1.10575e+05 Fmax= 3.35253e+03, atom= 149
# Step=  300, Dmax= 5.3e-03 nm, Epot= -1.10591e+05 Fmax= 4.92545e+03, atom= 149
# Step=  301, Dmax= 6.3e-03 nm, Epot= -1.10609e+05 Fmax= 4.73667e+03, atom= 149
# Step=  302, Dmax= 7.6e-03 nm, Epot= -1.10618e+05 Fmax= 7.12489e+03, atom= 149
# Step=  303, Dmax= 9.1e-03 nm, Epot= -1.10636e+05 Fmax= 6.83375e+03, atom= 149
# Step=  305, Dmax= 5.5e-03 nm, Epot= -1.10669e+05 Fmax= 1.67312e+03, atom= 149
# Step=  306, Dmax= 6.6e-03 nm, Epot= -1.10691e+05 Fmax= 8.13230e+03, atom= 149
# Step=  307, Dmax= 7.9e-03 nm, Epot= -1.10728e+05 Fmax= 4.10538e+03, atom= 149
# Step=  309, Dmax= 4.7e-03 nm, Epot= -1.10747e+05 Fmax= 3.09341e+03, atom= 149
# Step=  310, Dmax= 5.7e-03 nm, Epot= -1.10760e+05 Fmax= 5.81078e+03, atom= 149
# Step=  311, Dmax= 6.8e-03 nm, Epot= -1.10781e+05 Fmax= 4.59593e+03, atom= 149
# Step=  312, Dmax= 8.2e-03 nm, Epot= -1.10783e+05 Fmax= 8.15253e+03, atom= 149
# Step=  313, Dmax= 9.8e-03 nm, Epot= -1.10807e+05 Fmax= 6.86857e+03, atom= 149
# Step=  315, Dmax= 5.9e-03 nm, Epot= -1.10839e+05 Fmax= 2.27164e+03, atom= 149
# Step=  316, Dmax= 7.0e-03 nm, Epot= -1.10847e+05 Fmax= 8.36846e+03, atom= 149
# Step=  317, Dmax= 8.5e-03 nm, Epot= -1.10884e+05 Fmax= 4.77793e+03, atom= 149
# Step=  319, Dmax= 5.1e-03 nm, Epot= -1.10904e+05 Fmax= 2.97676e+03, atom= 149
# Step=  320, Dmax= 6.1e-03 nm, Epot= -1.10914e+05 Fmax= 6.59382e+03, atom= 149
# Step=  321, Dmax= 7.3e-03 nm, Epot= -1.10938e+05 Fmax= 4.60741e+03, atom= 149
# Step=  323, Dmax= 4.4e-03 nm, Epot= -1.10959e+05 Fmax= 2.24014e+03, atom= 149
# Step=  324, Dmax= 5.3e-03 nm, Epot= -1.10974e+05 Fmax= 5.70531e+03, atom= 149
# Step=  325, Dmax= 6.3e-03 nm, Epot= -1.10996e+05 Fmax= 4.13509e+03, atom= 149
# Step=  326, Dmax= 7.6e-03 nm, Epot= -1.11000e+05 Fmax= 7.42643e+03, atom= 149
# Step=  327, Dmax= 9.1e-03 nm, Epot= -1.11021e+05 Fmax= 6.71071e+03, atom= 149
# Step=  329, Dmax= 5.5e-03 nm, Epot= -1.11051e+05 Fmax= 1.65306e+03, atom= 149
# Step=  330, Dmax= 6.5e-03 nm, Epot= -1.11064e+05 Fmax= 8.76534e+03, atom= 149
# Step=  331, Dmax= 7.9e-03 nm, Epot= -1.11107e+05 Fmax= 3.30423e+03, atom= 149
# Step=  333, Dmax= 4.7e-03 nm, Epot= -1.11121e+05 Fmax= 4.08457e+03, atom= 149
# Step=  334, Dmax= 5.7e-03 nm, Epot= -1.11136e+05 Fmax= 4.54944e+03, atom= 149
# Step=  335, Dmax= 6.8e-03 nm, Epot= -1.11146e+05 Fmax= 6.04667e+03, atom= 149
# Step=  336, Dmax= 8.1e-03 nm, Epot= -1.11160e+05 Fmax= 6.43273e+03, atom= 149
# Step=  337, Dmax= 9.8e-03 nm, Epot= -1.11161e+05 Fmax= 8.77320e+03, atom= 149
# Step=  338, Dmax= 1.2e-02 nm, Epot= -1.11172e+05 Fmax= 9.23283e+03, atom= 149
# Step=  340, Dmax= 7.0e-03 nm, Epot= -1.11222e+05 Fmax= 1.68557e+03, atom= 149
# Step=  341, Dmax= 8.4e-03 nm, Epot= -1.11222e+05 Fmax= 1.10011e+04, atom= 149
# Step=  342, Dmax= 1.0e-02 nm, Epot= -1.11282e+05 Fmax= 4.71922e+03, atom= 149
# Step=  344, Dmax= 6.1e-03 nm, Epot= -1.11298e+05 Fmax= 4.57906e+03, atom= 149
# Step=  345, Dmax= 7.3e-03 nm, Epot= -1.11304e+05 Fmax= 6.80286e+03, atom= 149
# Step=  346, Dmax= 8.8e-03 nm, Epot= -1.11319e+05 Fmax= 6.62558e+03, atom= 149
# Step=  348, Dmax= 5.3e-03 nm, Epot= -1.11349e+05 Fmax= 1.54204e+03, atom= 149
# Step=  349, Dmax= 6.3e-03 nm, Epot= -1.11366e+05 Fmax= 7.91143e+03, atom= 149
# Step=  350, Dmax= 7.6e-03 nm, Epot= -1.11401e+05 Fmax= 3.83990e+03, atom= 149
# Step=  352, Dmax= 4.5e-03 nm, Epot= -1.11416e+05 Fmax= 3.08915e+03, atom= 149
# Step=  353, Dmax= 5.4e-03 nm, Epot= -1.11427e+05 Fmax= 5.44508e+03, atom= 149
# Step=  354, Dmax= 6.5e-03 nm, Epot= -1.11444e+05 Fmax= 4.56759e+03, atom= 149
# Step=  355, Dmax= 7.8e-03 nm, Epot= -1.11445e+05 Fmax= 7.66291e+03, atom= 149
# Step=  356, Dmax= 9.4e-03 nm, Epot= -1.11464e+05 Fmax= 6.78553e+03, atom= 149
# Step=  358, Dmax= 5.6e-03 nm, Epot= -1.11495e+05 Fmax= 1.98919e+03, atom= 149
# Step=  359, Dmax= 6.8e-03 nm, Epot= -1.11500e+05 Fmax= 8.25084e+03, atom= 149
# Step=  360, Dmax= 8.1e-03 nm, Epot= -1.11536e+05 Fmax= 4.37302e+03, atom= 149
# Step=  362, Dmax= 4.9e-03 nm, Epot= -1.11552e+05 Fmax= 3.08844e+03, atom= 149
# Step=  363, Dmax= 5.9e-03 nm, Epot= -1.11560e+05 Fmax= 6.07888e+03, atom= 149
# Step=  364, Dmax= 7.0e-03 nm, Epot= -1.11579e+05 Fmax= 4.69587e+03, atom= 149
# Step=  366, Dmax= 4.2e-03 nm, Epot= -1.11598e+05 Fmax= 1.87229e+03, atom= 149
# Step=  367, Dmax= 5.1e-03 nm, Epot= -1.11612e+05 Fmax= 5.76692e+03, atom= 149
# Step=  368, Dmax= 6.1e-03 nm, Epot= -1.11634e+05 Fmax= 3.67629e+03, atom= 149
# Step=  370, Dmax= 3.6e-03 nm, Epot= -1.11649e+05 Fmax= 1.88604e+03, atom= 149
# Step=  371, Dmax= 4.4e-03 nm, Epot= -1.11663e+05 Fmax= 5.01261e+03, atom= 149
# Step=  372, Dmax= 5.2e-03 nm, Epot= -1.11682e+05 Fmax= 3.02234e+03, atom= 149
# Step=  373, Dmax= 6.3e-03 nm, Epot= -1.11686e+05 Fmax= 6.83018e+03, atom= 149
# Step=  374, Dmax= 7.6e-03 nm, Epot= -1.11709e+05 Fmax= 4.76392e+03, atom= 149
# Step=  376, Dmax= 4.5e-03 nm, Epot= -1.11727e+05 Fmax= 2.29283e+03, atom= 149
# Step=  377, Dmax= 5.4e-03 nm, Epot= -1.11737e+05 Fmax= 5.95912e+03, atom= 149
# Step=  378, Dmax= 6.5e-03 nm, Epot= -1.11757e+05 Fmax= 4.18568e+03, atom= 149
# Step=  380, Dmax= 3.9e-03 nm, Epot= -1.11774e+05 Fmax= 1.80408e+03, atom= 149
# Step=  381, Dmax= 4.7e-03 nm, Epot= -1.11787e+05 Fmax= 5.61129e+03, atom= 149
# Step=  382, Dmax= 5.6e-03 nm, Epot= -1.11808e+05 Fmax= 3.03586e+03, atom= 149
# Step=  384, Dmax= 3.4e-03 nm, Epot= -1.11822e+05 Fmax= 2.25539e+03, atom= 149
# Step=  385, Dmax= 4.1e-03 nm, Epot= -1.11835e+05 Fmax= 3.90684e+03, atom= 149
# Step=  386, Dmax= 4.9e-03 nm, Epot= -1.11848e+05 Fmax= 3.69088e+03, atom= 149
# Step=  387, Dmax= 5.8e-03 nm, Epot= -1.11857e+05 Fmax= 5.24288e+03, atom= 149
# Step=  388, Dmax= 7.0e-03 nm, Epot= -1.11869e+05 Fmax= 5.66827e+03, atom= 149
# Step=  389, Dmax= 8.4e-03 nm, Epot= -1.11873e+05 Fmax= 7.24040e+03, atom= 149
# Step=  390, Dmax= 1.0e-02 nm, Epot= -1.11878e+05 Fmax= 8.43418e+03, atom= 149
# Step=  392, Dmax= 6.1e-03 nm, Epot= -1.11920e+05 Fmax= 8.82104e+02, atom= 149
#
# writing lowest energy coordinates.
#
# Back Off! I just backed up em.gro to ./#em.gro.1#
#
# Steepest Descents converged to Fmax < 1000 in 393 steps
# Potential Energy  = -1.1191986e+05
# Maximum force     =  8.8210370e+02 on atom 149
# Norm of force     =  4.0523765e+01
#
# GROMACS reminds you: "Wild Pointers Couldn't Drag Me Away" (K.A. Feenstra)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f nvt.mdp -c em.gro -p topol.top -o nvt.tpr
# !gmx mdrun -v -deffnm nvt
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f nvt.mdp -c em.gro -p topol.top -o nvt.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -1076135042
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# turning all bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning all bonds into constraints...
#
# NOTE 1 [file unknown]:
#   You are using constraints on all bonds, whereas the forcefield has been
#   parametrized only with constraints involving hydrogen atoms. We suggest
#   using constraints = h-bonds instead, this will also improve performance.
#
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group System is 13671.00
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.036 nm, buffer size 0.036 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.114 0.114 0.114
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 9 Mb of data
#
# There was 1 note
#
# Back Off! I just backed up nvt.tpr to ./#nvt.tpr.1#
#
# GROMACS reminds you: "Praise those of your critics for whom nothing is up to standard." (Dag Hammarskjold)
#
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -v -deffnm nvt
#
#
# Back Off! I just backed up nvt.log to ./#nvt.log.1#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file nvt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Changing nstlist from 10 to 40, rlist from 1 to 1.097
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Back Off! I just backed up nvt.trr to ./#nvt.trr.1#
#
# Back Off! I just backed up nvt.edr to ./#nvt.edr.1#
# starting mdrun 'Protein in water'
# 50000 steps,    100.0 ps.
# step 49900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 50000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1358.610      113.219     1200.0
#                  (ns/day)    (hour/ns)
# Performance:       76.314        0.314
#
# GROMACS reminds you: "A scientific truth does not triumph by convincing its opponents and making them see the light, but rather because its opponents eventually die and a new generation grows up that is familiar with it." (Max Planck)

# %% [markdown]
# ### Visualize data using matplotlib.

# %%
# %%writefile /content/drive/MyDrive/Rayca_eval/MD_simulation/npt.mdp
# ; NPT equilibration
# title                   = NPT Equilibration
# define                  = -DPOSRES  ; Position restrain the protein
# integrator              = md        ; Molecular dynamics algorithm
# dt                      = 0.002     ; Time step (ps)
# nsteps                  = 50000     ; 100 ps
# nstxout                 = 5000      ; Save coordinates every 10 ps
# nstvout                 = 5000      ; Save velocities every 10 ps
# nstenergy               = 1000      ; Save energies every 2 ps
# nstlog                  = 1000      ; Write log every 2 ps
#
# ; Neighbor searching
# cutoff-scheme           = Verlet
# nstlist                 = 10
# rlist                   = 1.0
# rcoulomb                = 1.0
# rvdw                    = 1.0
#
# ; Electrostatics
# coulombtype             = PME
# pme_order               = 4
# fourierspacing          = 0.16
#
# ; Van der Waals interactions
# vdw-modifier            = force-switch
# rvdw-switch             = 0.9
#
# ; Temperature coupling
# tcoupl                  = V-rescale
# tc-grps                 = Protein Non-Protein
# tau-t                   = 0.1  0.1
# ref-t                   = 300  300
#
# ; Pressure coupling
# pcoupl                  = Berendsen
# pcoupltype              = isotropic
# tau-p                   = 2.0
# ref-p                   = 1.0
# compressibility         = 4.5e-5
#
# ; Constraints (FIXED)
# constraints             = h-bonds
# constraint_algorithm    = LINCS
# lincs_iter              = 1
# lincs_order             = 4
# Out:
# Overwriting /content/drive/MyDrive/Rayca_eval/MD_simulation/npt.mdp

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f npt.mdp -c nvt.gro -r nvt.gro -p topol.top -o npt.tpr -maxwarn 1
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f npt.mdp -c nvt.gro -r nvt.gro -p topol.top -o npt.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'title'
# Setting the LD random seed to -490997773
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 375.92
# Number of degrees of freedom in T-Coupling group non-Protein is 13371.08
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.036 nm, buffer size 0.036 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 1 [file npt.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
#
# WARNING 1 [file npt.mdp]:
#   You are using pressure coupling with absolute position restraints, this
#   will give artifacts. Use the refcoord_scaling option.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.147 0.147 0.147
#
# Estimate for the relative computational load of the PME mesh part: 0.16
#
# This run will generate roughly 2 Mb of data
#
# There was 1 note
#
# There was 1 warning
#
# GROMACS reminds you: "They're Red Hot" (Red Hot Chili Peppers)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx mdrun -deffnm npt -v
# Out:
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -deffnm npt -v
#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file npt.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Changing nstlist from 10 to 40, rlist from 1 to 1.097
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Protein in water'
# 50000 steps,    100.0 ps.
# step 49900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 50000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1463.917      121.996     1200.0
#                  (ns/day)    (hour/ns)
# Performance:       70.823        0.339
#
# GROMACS reminds you: "Wedged as we are between two eternities of idleness, there is no excuse for being idle now" (Anthony Burgess)

# %% [markdown]
# ### Visualize data using matplotlib.

# %%
# %%writefile /content/drive/MyDrive/Rayca_eval/MD_simulation/md.mdp
#
# ; Production MD run for 100 ns
#
# integrator              = md
# dt                      = 0.002
# nsteps                  = 50000000    ; 100 ns
# nstxout                 = 50000       ; Save coordinates every 100 ps
# nstvout                 = 50000       ; Save velocities every 100 ps
# nstenergy               = 5000        ; Save energies every 10 ps
# nstlog                  = 5000        ; Save log every 10 ps
# nstxout-compressed      = 5000        ; Save compressed trajectory every 10 ps
# compressed-x-precision  = 1000
# continuation            = yes         ; Restarting simulation
# constraint_algorithm    = lincs
# constraints             = h-bonds     ; Only constrain bonds with hydrogens
# lincs_iter              = 1
# lincs_order             = 4
# cutoff-scheme           = Verlet
# nstlist                 = 20
# ns_type                 = grid
# rlist                   = 1.0
# rvdw                    = 1.0
# coulombtype             = PME
# rcoulomb                = 1.0
# vdw-modifier            = Force-switch
# rvdw-switch             = 0.9
# tcoupl                  = V-rescale
# tc-grps                 = Protein Non-Protein
# tau-t                   = 0.1 0.1
# ref-t                   = 300 300
# pcoupl                  = Parrinello-Rahman
# pcoupltype              = isotropic
# tau-p                   = 2.0
# ref-p                   = 1.0
# compressibility         = 4.5e-5
# refcoord_scaling        = com
# gen_vel                 = no
# Out:
# Writing /content/drive/MyDrive/Rayca_eval/MD_simulation/md.mdp

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx grompp -f md.mdp -c npt.gro -t npt.cpt -p topol.top -o md.tpr -maxwarn 1
# Out:
#               :-) GROMACS - gmx grompp, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx grompp -f md.mdp -c npt.gro -t npt.cpt -p topol.top -o md.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -9700353
#
# Generated 330891 of the 330891 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 330891 of the 330891 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
# Analysing residue names:
# There are:     9    Protein residues
# There are:  2229      Water residues
# Analysing Protein...
# Number of degrees of freedom in T-Coupling group Protein is 375.92
# Number of degrees of freedom in T-Coupling group non-Protein is 13371.08
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.100 nm, buffer size 0.100 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.030 nm, buffer size 0.030 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  100.000
#
# Using frame at t = 100 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.114 0.114 0.114
#
# Estimate for the relative computational load of the PME mesh part: 0.17
#
# This run will generate roughly 523 Mb of data
#
# GROMACS reminds you: "I Was Born to Have Adventure" (F. Zappa)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx mdrun -v -deffnm md -ntmpi 1 -ntomp 12
# Out:
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -v -deffnm md -ntmpi 1 -ntomp 12
#
#
# Back Off! I just backed up md.log to ./#md.log.4#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Changing nstlist from 20 to 40, rlist from 1.03 to 1.097
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Back Off! I just backed up md.xtc to ./#md.xtc.3#
#
# Back Off! I just backed up md.trr to ./#md.trr.3#
#
# Back Off! I just backed up md.edr to ./#md.edr.3#
# starting mdrun 'Protein in water'
# 50000000 steps, 100000.0 ps.
# step 9942900, will finish Thu Mar 20 13:22:30 2025

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx mdrun -v -deffnm md -ntmpi 1 -ntomp 12 -cpi md.cpt -noappend
# Out:
#               :-) GROMACS - gmx mdrun, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx mdrun -v -deffnm md -ntmpi 1 -ntomp 12 -cpi md.cpt -noappend
#
# Compiled SIMD: SSE4.1, but for this host/run AVX_512 might be better (see
# log).
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Changing nstlist from 20 to 40, rlist from 1.031 to 1.097
#
# Using 1 MPI thread
# Using 12 OpenMP threads
#
# starting mdrun 'Protein in water'
# 50000000 steps, 100000.0 ps (continuing from step 43372160,  86744.3 ps).
# step 49999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 50000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:   194674.113    16222.857     1200.0
#                          4h30:22
#                  (ns/day)    (hour/ns)
# Performance:       70.597        0.340
#
# GROMACS reminds you: "It's So Fast It's Slow" (F. Black)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !gmx trjcat -f md.xtc md.part0002.xtc md.part0003.xtc md.part0004.xtc md.part0005.xtc md.part0006.xtc md.part0007.xtc -o full_md.xtc -cat
# Out:
#               :-) GROMACS - gmx trjcat, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjcat, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx trjcat -f md.xtc md.part0002.xtc md.part0003.xtc md.part0004.xtc md.part0005.xtc md.part0006.xtc md.part0007.xtc -o full_md.xtc -cat
#
# Reading frame       1 time 86760.000
#
# Summary of files and start times used:
#
#           File                Start time       Time step
# ---------------------------------------------------------
#                    md.xtc        0.000 ps       10.000 ps
#           md.part0002.xtc    19570.000 ps       10.000 ps
#           md.part0003.xtc    34130.000 ps       10.000 ps
#           md.part0004.xtc    56620.000 ps       10.000 ps
#           md.part0005.xtc    61700.000 ps       10.000 ps
#           md.part0006.xtc    85260.000 ps       10.000 ps
#           md.part0007.xtc    86750.000 ps       10.000 ps
#
# Reading frame       0 time    0.000   Note that major changes are planned in future for trjcat, to improve usability and utility.
# lasttime 0
#
# Continue writing frames from md.xtc t=0 ps, frame=0
#  ->  frame   1740 time 17400.000 ps
# WARNING: Frames around t=17400.000000 ps have a different spacing than the rest,
# might be a gap or overlap that couldn't be corrected automatically.
# Reading frame       0 time 19570.000
# lasttime 17400
#
# Continue writing frames from md.part0002.xtc t=19570 ps, frame=1741
#  ->  frame   3190 time 34060.000 ps
# Reading frame       0 time 34130.000
# lasttime 34120
#
# Continue writing frames from md.part0003.xtc t=34130 ps, frame=3197
#  ->  frame   5370 time 55860.000 ps
# WARNING: Frames around t=55890.000000 ps have a different spacing than the rest,
# might be a gap or overlap that couldn't be corrected automatically.
# Reading frame       0 time 56620.000
# lasttime 55890
#
# Continue writing frames from md.part0004.xtc t=56620 ps, frame=5374
#  ->  frame   5590 time 58780.000 ps
# WARNING: Frames around t=58790.000000 ps have a different spacing than the rest,
# might be a gap or overlap that couldn't be corrected automatically.
# Reading frame       0 time 61700.000
# lasttime 58790
#
# Continue writing frames from md.part0005.xtc t=61700 ps, frame=5592
#  ->  frame   7940 time 85180.000 ps
# WARNING: Frames around t=85190.000000 ps have a different spacing than the rest,
# might be a gap or overlap that couldn't be corrected automatically.
# Reading frame       0 time 85260.000
# lasttime 85190
#
# Continue writing frames from md.part0006.xtc t=85260 ps, frame=7942
# Reading frame      70 time 85960.000
# WARNING: Frames around t=86000.000000 ps have a different spacing than the rest,
# might be a gap or overlap that couldn't be corrected automatically.
# Reading frame       0 time 86750.000
# lasttime 86000
#
# Continue writing frames from md.part0007.xtc t=86750 ps, frame=8017
#  ->  frame   9340 time 99980.000 ps
#
# Last frame written was 9342, time 100000.000000 ps
#
# GROMACS reminds you: "It's So Lonely When You Don't Even Know Yourself" (Red Hot Chili Peppers)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
`

# %% [markdown]
# ### Calculate RMSD (Root Mean Square Deviation) of trajectory.

# %%
# !echo -e "Protein\nProtein" | gmx rms -s md.tpr -f full_md.xtc -o rmsd_pocket.xvg -tu ns
# Out:
#                :-) GROMACS - gmx rms, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rms, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx rms -s md.tpr -f full_md.xtc -o rmsd_pocket.xvg -tu ns
#
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Select group for least squares fit
# Group     0 (         System) has  6838 elements
# Group     1 (        Protein) has   151 elements
# Group     2 (      Protein-H) has    74 elements
# Group     3 (        C-alpha) has     9 elements
# Group     4 (       Backbone) has    27 elements
# Group     5 (      MainChain) has    37 elements
# Group     6 (   MainChain+Cb) has    46 elements
# Group     7 (    MainChain+H) has    46 elements
# Group     8 (      SideChain) has   105 elements
# Group     9 (    SideChain-H) has    37 elements
# Group    10 (    Prot-Masses) has   151 elements
# Group    11 (    non-Protein) has  6687 elements
# Group    12 (          Water) has  6687 elements
# Group    13 (            SOL) has  6687 elements
# Group    14 (      non-Water) has   151 elements
# Select a group: Selected 1: 'Protein'
# Select group for RMSD calculation
# Group     0 (         System) has  6838 elements
# Group     1 (        Protein) has   151 elements
# Group     2 (      Protein-H) has    74 elements
# Group     3 (        C-alpha) has     9 elements
# Group     4 (       Backbone) has    27 elements
# Group     5 (      MainChain) has    37 elements
# Group     6 (   MainChain+Cb) has    46 elements
# Group     7 (    MainChain+H) has    46 elements
# Group     8 (      SideChain) has   105 elements
# Group     9 (    SideChain-H) has    37 elements
# Group    10 (    Prot-Masses) has   151 elements
# Group    11 (    non-Protein) has  6687 elements
# Group    12 (          Water) has  6687 elements
# Group    13 (            SOL) has  6687 elements
# Group    14 (      non-Water) has   151 elements
# Select a group: Selected 1: 'Protein'
# Reading frame    9000 time   96.580
#
# GROMACS reminds you: "There is no such thing as free energy. Anyone who advocates it does not know what he is talking about." (Alireza Haghighat)

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.

# %%
# !echo 4 1 | gmx trjconv -s md.tpr -f full_md.xtc -o aligned.xtc -fit rot+trans
# Out:
#              :-) GROMACS - gmx trjconv, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx trjconv -s md.tpr -f full_md.xtc -o aligned.xtc -fit rot+trans
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Select group for least squares fit
# Group     0 (         System) has  6838 elements
# Group     1 (        Protein) has   151 elements
# Group     2 (      Protein-H) has    74 elements
# Group     3 (        C-alpha) has     9 elements
# Group     4 (       Backbone) has    27 elements
# Group     5 (      MainChain) has    37 elements
# Group     6 (   MainChain+Cb) has    46 elements
# Group     7 (    MainChain+H) has    46 elements
# Group     8 (      SideChain) has   105 elements
# Group     9 (    SideChain-H) has    37 elements
# Group    10 (    Prot-Masses) has   151 elements
# Group    11 (    non-Protein) has  6687 elements
# Group    12 (          Water) has  6687 elements
# Group    13 (            SOL) has  6687 elements
# Group    14 (      non-Water) has   151 elements
# Select a group: Selected 4: 'Backbone'
# Select group for output
# Group     0 (         System) has  6838 elements
# Group     1 (        Protein) has   151 elements
# Group     2 (      Protein-H) has    74 elements
# Group     3 (        C-alpha) has     9 elements
# Group     4 (       Backbone) has    27 elements
# Group     5 (      MainChain) has    37 elements
# Group     6 (   MainChain+Cb) has    46 elements
# Group     7 (    MainChain+H) has    46 elements
# Group     8 (      SideChain) has   105 elements
# Group     9 (    SideChain-H) has    37 elements
# Group    10 (    Prot-Masses) has   151 elements
# Group    11 (    non-Protein) has  6687 elements
# Group    12 (          Water) has  6687 elements
# Group    13 (            SOL) has  6687 elements
# Group    14 (      non-Water) has   151 elements
# Select a group: Selected 1: 'Protein'
# Reading frame       0 time    0.000
# Precision of full_md.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up aligned.xtc to ./#aligned.xtc.2#
#  ->  frame   9340 time 99980.000
#
#
# GROMACS reminds you: "Making merry out of nothing, like in refugee camp" (Gogol Bordello)

# %% [markdown]
# ### Calculate RMSF (Root Mean Square Fluctuation) of residues.

# %%
# !echo 1 | gmx rmsf -s md.tpr -f aligned.xtc -o rmsf_protein.xvg -res
# Out:
#                :-) GROMACS - gmx rmsf, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx rmsf, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx rmsf -s md.tpr -f aligned.xtc -o rmsf_protein.xvg -res
#
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Select group(s) for root mean square calculation
# Group     0 (         System) has  6838 elements
# Group     1 (        Protein) has   151 elements
# Group     2 (      Protein-H) has    74 elements
# Group     3 (        C-alpha) has     9 elements
# Group     4 (       Backbone) has    27 elements
# Group     5 (      MainChain) has    37 elements
# Group     6 (   MainChain+Cb) has    46 elements
# Group     7 (    MainChain+H) has    46 elements
# Group     8 (      SideChain) has   105 elements
# Group     9 (    SideChain-H) has    37 elements
# Group    10 (    Prot-Masses) has   151 elements
# Group    11 (    non-Protein) has  6687 elements
# Group    12 (          Water) has  6687 elements
# Group    13 (            SOL) has  6687 elements
# Group    14 (      non-Water) has   151 elements
# Select a group: Selected 1: 'Protein'
# Reading frame    9000 time 96580.000
#
# Back Off! I just backed up rmsf_protein.xvg to ./#rmsf_protein.xvg.1#
#
# GROMACS reminds you: "A real scientist solves problems, not wails that they are unsolvable." (Anne McCaffrey)

# %% [markdown]
# ### Calculate SASA (Solvent Accessible Surface Area) over the trajectory.

# %%
# !echo "Protein" | gmx sasa -s md.tpr -f full_md.xtc -o sasa_pocket.xvg -or sasa_residue.xvg -surface 'Protein'
# Out:
#                :-) GROMACS - gmx sasa, 2021.4-Ubuntu-2021.4-2 (-:
#
#                             GROMACS is written by:
#      Andrey Alekseenko              Emile Apol              Rossen Apostolov
#          Paul Bauer           Herman J.C. Berendsen           Par Bjelkmar
#        Christian Blau           Viacheslav Bolnykh             Kevin Boyd
#      Aldert van Buuren           Rudi van Drunen             Anton Feenstra
#     Gilles Gouaillardet             Alan Gray               Gerrit Groenhof
#        Anca Hamuraru            Vincent Hindriksen          M. Eric Irrgang
#       Aleksei Iupinov           Christoph Junghans             Joe Jordan
#     Dimitrios Karkoulis            Peter Kasson                Jiri Kraus
#       Carsten Kutzner              Per Larsson              Justin A. Lemkul
#        Viveca Lindahl            Magnus Lundborg             Erik Marklund
#         Pascal Merz             Pieter Meulenhoff            Teemu Murtola
#         Szilard Pall               Sander Pronk              Roland Schulz
#        Michael Shirts            Alexey Shvetsov             Alfons Sijbers
#        Peter Tieleman              Jon Vincent              Teemu Virolainen
#      Christian Wennberg            Maarten Wolf              Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx sasa, version 2021.4-Ubuntu-2021.4-2
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /content/drive/MyDrive/Rayca_eval/MD_simulation
# Command line:
#   gmx sasa -s md.tpr -f full_md.xtc -o sasa_pocket.xvg -or sasa_residue.xvg -surface Protein
#
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
# Reading file md.tpr, VERSION 2021.4-Ubuntu-2021.4-2 (single precision)
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Reading frame    9000 time 96580.000
# Analyzed 9343 frames, last time 100000.000
#
# GROMACS reminds you: "Engage" (J.L. Picard)

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
import matplotlib.pyplot as plt

def read_xvg(file_path):
    with open(file_path, 'r') as f:
        lines = f.readlines()
    data = [line.strip().split() for line in lines if not line.startswith(('#', '@'))]
    x = [float(i[0]) for i in data]
    y = [float(i[1]) for i in data]
    return x, y

# RMSD Plot
rmsd_x, rmsd_y = read_xvg('/content/drive/MyDrive/Rayca_eval/MD_simulation/rmsd_pocket.xvg')
plt.figure(figsize=(8, 5))
plt.plot(rmsd_x, rmsd_y)
plt.xlabel('Time (ns)')
plt.ylabel('RMSD (nm)')
plt.title('Pocket RMSD')
plt.grid(True)
plt.savefig('/content/drive/MyDrive/Rayca_eval/analysis_plots/rmsd_pocket.png')
plt.show()
plt.close()

# RMSF Plot
rmsf_x, rmsf_y = read_xvg('/content/drive/MyDrive/Rayca_eval/MD_simulation/rmsf_protein.xvg')
plt.figure(figsize=(8, 5))
plt.plot(rmsf_x, rmsf_y)
plt.xlabel('Residue Index')
plt.ylabel('RMSF (nm)')
plt.title('Pocket RMSF')
plt.grid(True)
plt.savefig('/content/drive/MyDrive/Rayca_eval/analysis_plots/rmsf_pocket.png')
plt.show()
plt.close()

# SASA Plot
sasa_x, sasa_y = read_xvg('/content/drive/MyDrive/Rayca_eval/MD_simulation/sasa_pocket.xvg')
plt.figure(figsize=(8, 5))
plt.plot(sasa_x, sasa_y)
plt.xlabel('Time (ns)')
plt.ylabel('SASA (nm²)')
plt.title('Pocket SASA')
plt.grid(True)
plt.savefig('/content/drive/MyDrive/Rayca_eval/analysis_plots/sasa_pocket.png')
plt.show()
plt.close()

# %% [markdown]
# ### Calculate RMSF (Root Mean Square Fluctuation) of residues.

# %%
#continuous Residue number plot RMSF

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load RMSF data (residue numbers and values)
data = np.loadtxt('/content/drive/MyDrive/Rayca_eval/MD_simulation/rmsf_pocket.xvg', comments=['#', '@'])

residue_numbers = data[:, 0]  # Original residue numbers
rmsf_values = data[:, 1]      # RMSF values

# Create a continuous x-axis (1,2,3,...)
x_axis = np.arange(1, len(residue_numbers) + 1)  # Continuous numbering

# Plot RMSF with continuous indexing
plt.figure(figsize=(8,5))
plt.plot(x_axis, rmsf_values, marker='o', linestyle='-', color='b', label="RMSF")
plt.xlabel("Residue Index (Pocket)")
plt.ylabel("RMSF (nm)")
plt.title("Pocket RMSF (Fixed x-axis)")
plt.grid(True)
plt.legend()

# Save the fixed plot
plt.savefig("/content/drive/MyDrive/Rayca_eval/analysis_plots/rmsf_pocket_fixed.png")
plt.show()

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
from MDAnalysis.analysis import rms, contacts, hole2, align, pca, distances
# Out:
# WARNING:MDAnalysis.coordinates.AMBER:netCDF4 is not available. Writing AMBER ncdf files will be slow.
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/analysis/hole2/__init__.py:58: DeprecationWarning: Deprecated in version 2.8.0
# MDAnalysis.analysis.hole2 is deprecated in favour of the MDAKit madahole2 (https://www.mdanalysis.org/mdahole2/) and will be removed in MDAnalysis version 3.0.0
#   warnings.warn(wmsg, category=DeprecationWarning)
# /usr/local/lib/python3.11/dist-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt

# Define file paths
tpr_file = "/content/drive/MyDrive/Rayca_eval/MD_simulation/md.tpr"
xtc_file = "/content/drive/MyDrive/Rayca_eval/MD_simulation/full_md.xtc"

# Load trajectory
u = mda.Universe(tpr_file, xtc_file)

# Define pocket atoms (assuming it's already selected in the simulation)
pocket = u.select_atoms("protein and around 5.0 resid 25-216")  # Adjust selection if needed

print(f"Loaded {len(pocket)} pocket atoms from trajectory.")
# Out:
# Loaded 77 pocket atoms from trajectory.
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/XDR.py:253: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn(

# %% [markdown]
# ### Calculate RMSD (Root Mean Square Deviation) of trajectory.

# %%
# Align trajectory to first frame
R = rms.RMSD(u, u, select="protein and around 5.0 resid 25-216", ref_frame=0)
R.run()

# Extract RMSD data
rmsd_time = R.rmsd[:, 0] / 1000  # Convert ps to ns
rmsd_values = R.rmsd[:, 2]  # RMSD (nm)

# Plot RMSD
plt.figure(figsize=(8, 5))
plt.plot(rmsd_time, rmsd_values, label="Pocket RMSD", color='#377eb8', linewidth=2.5)
plt.xlabel("Time (ns)", fontsize=14)
plt.ylabel("RMSD (nm)", fontsize=14)
plt.title("Pocket RMSD Over Time", fontsize=16)
plt.legend(frameon=False, fontsize=12)
plt.savefig("/content/drive/MyDrive/Rayca_eval/analysis_plots/rmsd_pocket_traj.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
from MDAnalysis.analysis.rms import RMSF

# Calculate RMSF
rmsf = RMSF(pocket).run()

# Plot RMSF
plt.figure(figsize=(8, 5))
plt.plot(pocket.resids, rmsf.rmsf, label="Pocket RMSF", color='#e41a1c', linewidth=2.5)
plt.xlabel("Residue Index (Pocket)", fontsize=14)
plt.ylabel("RMSF (nm)", fontsize=14)
plt.title("Pocket Residue Fluctuations (RMSF)", fontsize=16)
plt.legend(frameon=False, fontsize=12)
#plt.savefig("/content/drive/MyDrive/Rayca_eval/analysis_plots/rmsf_pocket_traj.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/analysis/rms.py:1000: DeprecationWarning: The `rmsf` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.rmsd` instead.
#   warnings.warn(wmsg, DeprecationWarning)

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
import MDAnalysis as mda
import freesasa
import numpy as np
import matplotlib.pyplot as plt
import tempfile
import os

# Load Universe
tpr_file = "/content/drive/MyDrive/Rayca_eval/MD_simulation/md.tpr"
xtc_file = "/content/drive/MyDrive/Rayca_eval/MD_simulation/full_md.xtc"
u = mda.Universe(tpr_file, xtc_file)

# Define your pocket selection (use appropriate atom/group selection)
pocket = u.select_atoms("protein")

# Arrays to store results
sasa_values = []
times = []

# Create temporary directory for storing temp PDBs
with tempfile.TemporaryDirectory() as tmpdir:
    for ts in u.trajectory:
        pdb_path = os.path.join(tmpdir, "frame.pdb")

        # Write current pocket frame to temp PDB file
        pocket.write(pdb_path)

        # Load into FreeSASA
        structure = freesasa.Structure(pdb_path)
        result = freesasa.calc(structure)

        sasa_values.append(result.totalArea())
        times.append(ts.time / 1000)  # Convert ps to ns

# Plot SASA
plt.figure(figsize=(8, 5))
plt.plot(times, sasa_values, label="Pocket SASA", color='#66c2a5', linewidth=2.5)
plt.xlabel("Time (ns)", fontsize=14)
plt.ylabel("SASA (nm²)", fontsize=14)
plt.title("Pocket SASA Over Time", fontsize=16)
plt.legend(frameon=False, fontsize=12)
plt.savefig("/content/drive/MyDrive/Rayca_eval/analysis_plots/sasa_pocket_traj.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'tempfactors' Using default value of '0.0'
#   warnings.warn("Found no information for attr: '{}'"
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA  # ✅ Correct import

# Load your trajectory
u = mda.Universe("md.tpr", "full_md.xtc")
pocket = u.select_atoms("protein")  # Adjust if needed

# Collect pocket atom positions over time
coords = []

for ts in u.trajectory[::10]:  # stride to speed up
    coords.append(pocket.positions.copy())

coords = np.array(coords)  # shape: (n_frames, n_atoms, 3)
n_frames = coords.shape[0]

# Flatten for PCA
coords_2d = coords.reshape(n_frames, -1)

# Run PCA
pca_model = PCA(n_components=2)
pca_projection = pca_model.fit_transform(coords_2d)

# Plot PCA projection
plt.figure(figsize=(8, 5))
sc = plt.scatter(
    pca_projection[:, 0], pca_projection[:, 1],
    c=np.linspace(0, n_frames / 10, n_frames),  # time in ns
    cmap='viridis', alpha=0.85
)
plt.xlabel("PC1", fontsize=14)
plt.ylabel("PC2", fontsize=14)
plt.title("PCA: Pocket Shape Evolution", fontsize=16)
plt.colorbar(sc, label="Time (ns)")
plt.savefig("/content/drive/MyDrive/Rayca_eval/analysis_plots/pocket_pca_traj.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/XDR.py:253: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn(

# %% [markdown]
# ### Import required libraries for analysis and visualization.

# %%
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
from MDAnalysis.analysis import distances

# Load your simulation
u = mda.Universe("md.tpr", "full_md.xtc")
pocket = u.select_atoms("protein")  # adjust selection if needed

volumes = []
time_ns = []

for ts in u.trajectory[::10]:  # stride to speed things up
    dist_matrix = distances.distance_array(pocket.positions, pocket.positions)
    min_dist = dist_matrix[np.nonzero(dist_matrix)].min()  # avoid 0s from self-distance
    volumes.append(min_dist ** 3)  # cube of smallest distance as approx. volume
    time_ns.append(ts.time / 1000)  # convert to ns

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(time_ns, volumes, color='#984ea3', linewidth=2.5)
plt.xlabel("Time (ns)", fontsize=14)
plt.ylabel("Approximate Volume (nm³)", fontsize=14)
plt.title("Pocket Volume Over Time", fontsize=16)
plt.savefig("/content/drive/MyDrive/Rayca_eval/analysis_plots/pocket_volume_traj.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/XDR.py:253: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn(

# %% [markdown]
# ### Perform molecular dynamics simulation analysis step.
